# %% [markdown]
# # Generative Models as Data Augmentation in the Medical Domain
#
# ## 1. Overview
#
# This project tries to evaluate the quality of generative models for data augmentation in the medical domain.
#
# Data augmentation will be relying on geometric data augmentation, (variational) auto-encoder (e.g. stacked denoising, denoising auto-encoder, etc.), and generative adversarial neural networks (e.g. GAN, DCGAN, Wasserstein GAN, etc.) for instance.
#
# We will restrict ourself to three kind of models to generate new data and evaluate the (possible) improvement with regards to a final classification score (i.e. comparing results between augmented and non-augmented training sets).
#
# ### Datasets
#
# We will look into applying the above project on some (if not all) of the following datasets from the MedMNIST Classification Decathlon (https://medmnist.github.io/):
#
# | Dataset | Classification Type | Train size | Validation size | Test size |
# | :--- | :--- | :---: | :---: | :---: |
# | PathMNIST Pathology | Multi-Class (9) | 89,996 | 10,004 | 7,180 |
# | DermaMNIST Dermatoscope | Multi-Class (7) | 7,007 | 1,003 | 2,005 |
# | OctMNIST | Multi-Class (4) | 97,477 | 10,832 | 1,000 |
# | PneumoniaMNIST Chest X-ray | Binary-Class (2) |4,708 | 524 | 624 |
# | BreastMNIST Breast Ultrasound | Binary-Class (2) | 546 | 78 | 156 |
# | OrganMNIST_Axial Abdominal CT | Multi-Class (11) | 34,581 | 6,491 | 17,778 |
# | OragnMNIST_Coronal Abdominal CT | Multi-Class (11) |13,000 | 2,392 | 8,268 |
# | OrganMNIST_Sagittal Abdominal CT | Multi-Class (11) | 13,940 | 2,452 | 8,829 |
#
# ### Notes
#
# We will also provide a short report (in copy) explaining the choice of VAE, AE, and/or GAN models, outlining differences between datasets' results. We will also try to interprete and justify possible differences with regards to models, data specifications, visual features, and bibliography references used to support the choices made.

# %% [markdown]
# ## 2. Data and Library Imports
#
# ### Source
#
# We will retrieve the above dataset from the following website:
#
# > [MedMNIST v2: A Large-Scale Lightweight Benchmark for 2D and 3D Biomedical Image Classification](https://medmnist.com/), Jiancheng Yang,Rui Shi,Donglai Wei,Zequan Liu,Lin Zhao,Bilian Ke,Hanspeter Pfister,Bingbing Ni
#
# By following the instructions on their [github](https://github.com/MedMNIST/MedMNIST), we can download their ready-made module with the following instruction:
#
# ```sh
# pip install jupyter, ipywidgets, IProgress
# pip install medmnist
# ```
#
# And load it in a python or ipython instance:
#
# ```python
# import medmnist
# ```
#
# ### Library Imports

# %%
from python_scripts.classifier import run_classifier_pipeline
from python_scripts.variational_autoencoders import run_encoder_pipeline, one_hot
from python_scripts.data import retrieve_flag_info, import_dataset
from python_scripts.data import check_cuda_availability
from python_scripts.data import generate_augmented_dataset_condVAE
from python_scripts.data import generate_augmented_dataset_jointVAE

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Checks CUDA availability

# %%
check_cuda_availability()
# Out:
# True,0,<torch.cuda.device object at 0x7efd117f58e0>,1
# NVIDIA GeForce GTX 980 Ti

# %% [markdown]
# ### Data Imports

# %%
data_flags = ["pathmnist", "dermamnist", "octmnist", "pneumoniamnist", 
              "breastmnist", "organamnist", "organcmnist", "organsmnist"]

info_flags = {flag:retrieve_flag_info(flag) for flag in data_flags}

# %%
pathmnist = import_dataset("pathmnist", info_flags)
# Out:
# Using downloaded and verified file: /home/quentin/.medmnist/pathmnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/pathmnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/pathmnist.npz
# ===================
# Montage of randomly extracted images from the dataset:
# <PIL.Image.Image image mode=RGB size=280x280 at 0x7EFCEABAAA00>
# ===================

# %%
dermamnist = import_dataset("dermamnist", info_flags)
# Out:
# Using downloaded and verified file: /home/quentin/.medmnist/dermamnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/dermamnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/dermamnist.npz
# ===================
# Montage of randomly extracted images from the dataset:
# <PIL.Image.Image image mode=RGB size=280x280 at 0x7EFC76E71BE0>
# ===================

# %%
octmnist = import_dataset("octmnist", info_flags)
# Out:
# Using downloaded and verified file: /home/quentin/.medmnist/octmnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/octmnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/octmnist.npz
# ===================
# Montage of randomly extracted images from the dataset:
# <PIL.Image.Image image mode=L size=280x280 at 0x7EFC7CA81F70>
# ===================

# %%
pneumoniamnist = import_dataset("pneumoniamnist", info_flags)
# Out:
# Using downloaded and verified file: /home/quentin/.medmnist/pneumoniamnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/pneumoniamnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/pneumoniamnist.npz
# ===================
# Montage of randomly extracted images from the dataset:
# <PIL.Image.Image image mode=L size=280x280 at 0x7EFC76E5DE20>
# ===================

# %%
breastmnist = import_dataset("breastmnist", info_flags)
# Out:
# Using downloaded and verified file: /home/quentin/.medmnist/breastmnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/breastmnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/breastmnist.npz
# ===================
# Montage of randomly extracted images from the dataset:
# <PIL.Image.Image image mode=L size=280x280 at 0x7EFC7CAEDBE0>
# ===================

# %%
organamnist = import_dataset("organamnist", info_flags)
# Out:
# Using downloaded and verified file: /home/quentin/.medmnist/organamnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/organamnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/organamnist.npz
# ===================
# Montage of randomly extracted images from the dataset:
# <PIL.Image.Image image mode=L size=280x280 at 0x7EFC74F9BC40>
# ===================

# %%
organcmnist = import_dataset("organcmnist", info_flags)
# Out:
# Using downloaded and verified file: /home/quentin/.medmnist/organcmnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/organcmnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/organcmnist.npz
# ===================
# Montage of randomly extracted images from the dataset:
# <PIL.Image.Image image mode=L size=280x280 at 0x7EFC76FF0970>
# ===================

# %%
organsmnist = import_dataset("organsmnist", info_flags)
# Out:
# Using downloaded and verified file: /home/quentin/.medmnist/organsmnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/organsmnist.npz
# Using downloaded and verified file: /home/quentin/.medmnist/organsmnist.npz
# ===================
# Montage of randomly extracted images from the dataset:
# <PIL.Image.Image image mode=L size=280x280 at 0x7EFC7CA4E700>
# ===================

# %% [markdown]
# ## 3. Training a Classifier Without Data Augmentation
#
# ### PathMNIST

# %%
clf_base_pathmnist = run_classifier_pipeline("pathmnist", info_flags, pathmnist)
# Out:
# {
#   "python_class": "PathMNIST",
#   "description": "The PathMNIST is based on a prior study for predicting survival from colorectal cancer histology slides, providing a dataset (NCT-CRC-HE-100K) of 100,000 non-overlapping image patches from hematoxylin & eosin stained histological images, and a test dataset (CRC-VAL-HE-7K) of 7,180 image patches from a different clinical center. The dataset is comprised of 9 types of tissues, resulting in a multi-class classification task. We resize the source images of 3\u00d7224\u00d7224 into 3\u00d728\u00d728, and split NCT-CRC-HE-100K into training and validation set with a ratio of 9:1. The CRC-VAL-HE-7K is treated as the test set.",
#   "url": "https://zenodo.org/record/5208230/files/pathmnist.npz?download=1",
#   "MD5": "a8b06965200029087d5bd730944a56c1",
#   "task": "multi-class",
#   "label": {
#     "0": "adipose",
#     "1": "background",
#     "2": "debris",
#     "3": "lymphocytes",
#     "4": "mucus",
#     "5": "smooth muscle",
#     "6": "normal colon mucosa",
#     "7": "cancer-associated stroma",
#     "8": "colorectal adenocarcinoma epithelium"
#   },
#   "n_channels": 3,
#   "n_samples": {
#     "train": 89996,
#     "val": 10004,
#     "test": 7180
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             448
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                    [-1, 9]           1,161
# ================================================================
# Total params: 235,225
# Trainable params: 235,225
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.90
# Estimated Total Size (MB): 1.73
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|█████████████████████████████████████████| 704/704 [00:20<00:00, 34.59it/s]
# train -- accuracy: 0.72
# val -- accuracy: 0.98,  AUC: 0.76
# ===================
# Epoch 1
# 100%|█████████████████████████████████████████| 704/704 [00:20<00:00, 34.66it/s]
# train -- accuracy: 0.86
# val -- accuracy: 0.99,  AUC: 0.87
# ===================
# Epoch 2
# 100%|█████████████████████████████████████████| 704/704 [00:20<00:00, 35.03it/s]
# train -- accuracy: 0.9
# val -- accuracy: 0.99,  AUC: 0.77
# ===================
# Epoch 3
# 100%|█████████████████████████████████████████| 704/704 [00:19<00:00, 35.24it/s]
# train -- accuracy: 0.92
# val -- accuracy: 0.99,  AUC: 0.91
# ===================
# Epoch 4
# 100%|█████████████████████████████████████████| 704/704 [00:20<00:00, 35.13it/s]
# train -- accuracy: 0.93
# val -- accuracy: 0.99,  AUC: 0.88
# ===================
# Epoch 5
# 100%|█████████████████████████████████████████| 704/704 [00:20<00:00, 34.96it/s]
# train -- accuracy: 0.93
# val -- accuracy: 0.97,  AUC: 0.75
# ===================
# Epoch 6
# 100%|█████████████████████████████████████████| 704/704 [00:20<00:00, 34.88it/s]
# train -- accuracy: 0.93
# val -- accuracy: 1.0,  AUC: 0.91
# ===================
# Epoch 7
# 100%|█████████████████████████████████████████| 704/704 [00:20<00:00, 34.77it/s]
# train -- accuracy: 0.94
# val -- accuracy: 0.99,  AUC: 0.87
# ===================
# Epoch 8
# 100%|█████████████████████████████████████████| 704/704 [00:20<00:00, 34.79it/s]
# train -- accuracy: 0.95
# val -- accuracy: 1.0,  AUC: 0.94
# ===================
# Epoch 9
# 100%|█████████████████████████████████████████| 704/704 [00:20<00:00, 35.19it/s]
# train -- accuracy: 0.95
# val -- accuracy: 1.0,  AUC: 0.94
# ===================
# test -- accuracy: 0.97,  AUC: 0.81

# %% [markdown]
# ### DermaMNIST

# %%
clf_base_dermamnist = run_classifier_pipeline("dermamnist", info_flags, dermamnist)
# Out:
# {
#   "python_class": "DermaMNIST",
#   "description": "The DermaMNIST is based on the HAM10000, a large collection of multi-source dermatoscopic images of common pigmented skin lesions. The dataset consists of 10,015 dermatoscopic images categorized as 7 different diseases, formulized as a multi-class classification task. We split the images into training, validation and test set with a ratio of 7:1:2. The source images of 3\u00d7600\u00d7450 are resized into 3\u00d728\u00d728.",
#   "url": "https://zenodo.org/record/5208230/files/dermamnist.npz?download=1",
#   "MD5": "0744692d530f8e62ec473284d019b0c7",
#   "task": "multi-class",
#   "label": {
#     "0": "actinic keratoses and intraepithelial carcinoma",
#     "1": "basal cell carcinoma",
#     "2": "benign keratosis-like lesions",
#     "3": "dermatofibroma",
#     "4": "melanoma",
#     "5": "melanocytic nevi",
#     "6": "vascular lesions"
#   },
#   "n_channels": 3,
#   "n_samples": {
#     "train": 7007,
#     "val": 1003,
#     "test": 2005
#   },
#   "license": "CC BY-NC 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             448
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                    [-1, 7]             903
# ================================================================
# Total params: 234,967
# Trainable params: 234,967
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.90
# Estimated Total Size (MB): 1.73
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|███████████████████████████████████████████| 55/55 [00:01<00:00, 35.73it/s]
# train -- accuracy: 0.34
# val -- accuracy: 0.81,  AUC: 0.44
# ===================
# Epoch 1
# 100%|███████████████████████████████████████████| 55/55 [00:01<00:00, 36.08it/s]
# train -- accuracy: 0.51
# val -- accuracy: 0.89,  AUC: 0.62
# ===================
# Epoch 2
# 100%|███████████████████████████████████████████| 55/55 [00:01<00:00, 35.94it/s]
# train -- accuracy: 0.61
# val -- accuracy: 0.86,  AUC: 0.59
# ===================
# Epoch 3
# 100%|███████████████████████████████████████████| 55/55 [00:01<00:00, 34.80it/s]
# train -- accuracy: 0.71
# val -- accuracy: 0.88,  AUC: 0.55
# ===================
# Epoch 4
# 100%|███████████████████████████████████████████| 55/55 [00:01<00:00, 35.94it/s]
# train -- accuracy: 0.78
# val -- accuracy: 0.89,  AUC: 0.55
# ===================
# Epoch 5
# 100%|███████████████████████████████████████████| 55/55 [00:01<00:00, 35.44it/s]
# train -- accuracy: 0.82
# val -- accuracy: 0.87,  AUC: 0.55
# ===================
# Epoch 6
# 100%|███████████████████████████████████████████| 55/55 [00:01<00:00, 35.42it/s]
# train -- accuracy: 0.85
# val -- accuracy: 0.88,  AUC: 0.56
# ===================
# Epoch 7
# 100%|███████████████████████████████████████████| 55/55 [00:01<00:00, 34.83it/s]
# train -- accuracy: 0.88
# val -- accuracy: 0.86,  AUC: 0.49
# ===================
# Epoch 8
# 100%|███████████████████████████████████████████| 55/55 [00:01<00:00, 35.13it/s]
# train -- accuracy: 0.9
# val -- accuracy: 0.89,  AUC: 0.7
# ===================
# Epoch 9
# 100%|███████████████████████████████████████████| 55/55 [00:01<00:00, 34.81it/s]
# train -- accuracy: 0.91
# val -- accuracy: 0.87,  AUC: 0.68
# ===================
# test -- accuracy: 0.88,  AUC: 0.69

# %% [markdown]
# ### OctMNIST

# %%
clf_base_octmnist = run_classifier_pipeline("octmnist", info_flags, octmnist)
# Out:
# {
#   "python_class": "OCTMNIST",
#   "description": "The OCTMNIST is based on a prior dataset of 109,309 valid optical coherence tomography (OCT) images for retinal diseases. The dataset is comprised of 4 diagnosis categories, leading to a multi-class classification task. We split the source training set with a ratio of 9:1 into training and validation set, and use its source validation set as the test set. The source images are gray-scale, and their sizes are (384\u22121,536)\u00d7(277\u2212512). We center-crop the images and resize them into 1\u00d728\u00d728.",
#   "url": "https://zenodo.org/record/5208230/files/octmnist.npz?download=1",
#   "MD5": "c68d92d5b585d8d81f7112f81e2d0842",
#   "task": "multi-class",
#   "label": {
#     "0": "choroidal neovascularization",
#     "1": "diabetic macular edema",
#     "2": "drusen",
#     "3": "normal"
#   },
#   "n_channels": 1,
#   "n_samples": {
#     "train": 97477,
#     "val": 10832,
#     "test": 1000
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                    [-1, 4]             516
# ================================================================
# Total params: 234,292
# Trainable params: 234,292
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.89
# Estimated Total Size (MB): 1.72
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|█████████████████████████████████████████| 762/762 [00:19<00:00, 39.44it/s]
# train -- accuracy: 0.73
# val -- accuracy: 0.94,  AUC: 0.81
# ===================
# Epoch 1
# 100%|█████████████████████████████████████████| 762/762 [00:19<00:00, 39.77it/s]
# train -- accuracy: 0.83
# val -- accuracy: 0.96,  AUC: 0.87
# ===================
# Epoch 2
# 100%|█████████████████████████████████████████| 762/762 [00:19<00:00, 39.72it/s]
# train -- accuracy: 0.86
# val -- accuracy: 0.96,  AUC: 0.82
# ===================
# Epoch 3
# 100%|█████████████████████████████████████████| 762/762 [00:19<00:00, 38.81it/s]
# train -- accuracy: 0.88
# val -- accuracy: 0.96,  AUC: 0.82
# ===================
# Epoch 4
# 100%|█████████████████████████████████████████| 762/762 [00:20<00:00, 37.95it/s]
# train -- accuracy: 0.9
# val -- accuracy: 0.97,  AUC: 0.88
# ===================
# Epoch 5
# 100%|█████████████████████████████████████████| 762/762 [00:20<00:00, 38.10it/s]
# train -- accuracy: 0.91
# val -- accuracy: 0.97,  AUC: 0.88
# ===================
# Epoch 6
# 100%|█████████████████████████████████████████| 762/762 [00:19<00:00, 38.67it/s]
# train -- accuracy: 0.93
# val -- accuracy: 0.96,  AUC: 0.89
# ===================
# Epoch 7
# 100%|█████████████████████████████████████████| 762/762 [00:19<00:00, 38.79it/s]
# train -- accuracy: 0.93
# val -- accuracy: 0.97,  AUC: 0.88
# ===================
# Epoch 8
# 100%|█████████████████████████████████████████| 762/762 [00:19<00:00, 38.68it/s]
# train -- accuracy: 0.94
# val -- accuracy: 0.97,  AUC: 0.87
# ===================
# Epoch 9
# 100%|█████████████████████████████████████████| 762/762 [00:19<00:00, 38.64it/s]
# train -- accuracy: 0.95
# val -- accuracy: 0.97,  AUC: 0.86
# ===================
# test -- accuracy: 0.93,  AUC: 0.71

# %% [markdown]
# ### PneumoniaMNIST

# %%
clf_base_pneumoniamnist = run_classifier_pipeline("pneumoniamnist", info_flags, pneumoniamnist)
# Out:
# {
#   "python_class": "PneumoniaMNIST",
#   "description": "The PneumoniaMNIST is based on a prior dataset of 5,856 pediatric chest X-Ray images. The task is binary-class classification of pneumonia against normal. We split the source training set with a ratio of 9:1 into training and validation set and use its source validation set as the test set. The source images are gray-scale, and their sizes are (384\u22122,916)\u00d7(127\u22122,713). We center-crop the images and resize them into 1\u00d728\u00d728.",
#   "url": "https://zenodo.org/record/5208230/files/pneumoniamnist.npz?download=1",
#   "MD5": "28209eda62fecd6e6a2d98b1501bb15f",
#   "task": "binary-class",
#   "label": {
#     "0": "normal",
#     "1": "pneumonia"
#   },
#   "n_channels": 1,
#   "n_samples": {
#     "train": 4708,
#     "val": 524,
#     "test": 624
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                    [-1, 2]             258
# ================================================================
# Total params: 234,034
# Trainable params: 234,034
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.89
# Estimated Total Size (MB): 1.72
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|███████████████████████████████████████████| 37/37 [00:00<00:00, 37.71it/s]
# train -- accuracy: 0.85
# val -- accuracy: 0.97,  AUC: 0.74
# ===================
# Epoch 1
# 100%|███████████████████████████████████████████| 37/37 [00:00<00:00, 39.16it/s]
# train -- accuracy: 0.95
# val -- accuracy: 0.99,  AUC: 0.95
# ===================
# Epoch 2
# 100%|███████████████████████████████████████████| 37/37 [00:00<00:00, 39.09it/s]
# train -- accuracy: 0.97
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 3
# 100%|███████████████████████████████████████████| 37/37 [00:00<00:00, 38.50it/s]
# train -- accuracy: 0.98
# val -- accuracy: 1.0,  AUC: 0.97
# ===================
# Epoch 4
# 100%|███████████████████████████████████████████| 37/37 [00:00<00:00, 40.15it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.97
# ===================
# Epoch 5
# 100%|███████████████████████████████████████████| 37/37 [00:00<00:00, 39.95it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 6
# 100%|███████████████████████████████████████████| 37/37 [00:00<00:00, 40.18it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 7
# 100%|███████████████████████████████████████████| 37/37 [00:00<00:00, 39.91it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.97
# ===================
# Epoch 8
# 100%|███████████████████████████████████████████| 37/37 [00:00<00:00, 38.14it/s]
# train -- accuracy: 1.0
# val -- accuracy: 1.0,  AUC: 0.98
# ===================
# Epoch 9
# 100%|███████████████████████████████████████████| 37/37 [00:00<00:00, 39.07it/s]
# train -- accuracy: 1.0
# val -- accuracy: 1.0,  AUC: 0.98
# ===================
# test -- accuracy: 0.96,  AUC: 0.86

# %% [markdown]
# ### BreastMNIST

# %%
clf_base_breastmnist = run_classifier_pipeline("breastmnist", info_flags, breastmnist)
# Out:
# {
#   "python_class": "BreastMNIST",
#   "description": "The BreastMNIST is based on a dataset of 780 breast ultrasound images. It is categorized into 3 classes: normal, benign, and malignant. As we use low-resolution images, we simplify the task into binary classification by combining normal and benign as positive and classifying them against malignant as negative. We split the source dataset with a ratio of 7:1:2 into training, validation and test set. The source images of 1\u00d7500\u00d7500 are resized into 1\u00d728\u00d728.",
#   "url": "https://zenodo.org/record/5208230/files/breastmnist.npz?download=1",
#   "MD5": "750601b1f35ba3300ea97c75c52ff8f6",
#   "task": "binary-class",
#   "label": {
#     "0": "malignant",
#     "1": "normal, benign"
#   },
#   "n_channels": 1,
#   "n_samples": {
#     "train": 546,
#     "val": 78,
#     "test": 156
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                    [-1, 2]             258
# ================================================================
# Total params: 234,034
# Trainable params: 234,034
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.89
# Estimated Total Size (MB): 1.72
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 46.32it/s]
# train -- accuracy: 0.52
# val -- accuracy: 0.42,  AUC: 0.73
# ===================
# Epoch 1
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 44.55it/s]
# train -- accuracy: 0.54
# val -- accuracy: 0.47,  AUC: 0.73
# ===================
# Epoch 2
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 43.40it/s]
# train -- accuracy: 0.57
# val -- accuracy: 0.67,  AUC: 0.28
# ===================
# Epoch 3
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 44.11it/s]
# train -- accuracy: 0.68
# val -- accuracy: 0.72,  AUC: 0.27
# ===================
# Epoch 4
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 42.92it/s]
# train -- accuracy: 0.78
# val -- accuracy: 0.73,  AUC: 0.31
# ===================
# Epoch 5
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 43.74it/s]
# train -- accuracy: 0.76
# val -- accuracy: 0.76,  AUC: 0.33
# ===================
# Epoch 6
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 44.84it/s]
# train -- accuracy: 0.76
# val -- accuracy: 0.79,  AUC: 0.35
# ===================
# Epoch 7
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 42.54it/s]
# train -- accuracy: 0.82
# val -- accuracy: 0.83,  AUC: 0.46
# ===================
# Epoch 8
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 43.33it/s]
# train -- accuracy: 0.85
# val -- accuracy: 0.87,  AUC: 0.56
# ===================
# Epoch 9
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 26.78it/s]
# train -- accuracy: 0.87
# val -- accuracy: 0.89,  AUC: 0.64
# ===================
# test -- accuracy: 0.85,  AUC: 0.68

# %% [markdown]
# ### OrganAMNIST

# %%
clf_base_organamnist = run_classifier_pipeline("organamnist", info_flags, organamnist)
# Out:
# {
#   "python_class": "OrganAMNIST",
#   "description": "The OrganAMNIST is based on 3D computed tomography (CT) images from Liver Tumor Segmentation Benchmark (LiTS). It is renamed from OrganMNIST_Axial (in MedMNIST v1) for simplicity. We use bounding-box annotations of 11 body organs from another study to obtain the organ labels. Hounsfield-Unit (HU) of the 3D images are transformed into gray-scale with an abdominal window. We crop 2D images from the center slices of the 3D bounding boxes in axial views (planes). The images are resized into 1\u00d728\u00d728 to perform multi-class classification of 11 body organs. 115 and 16 CT scans from the source training set are used as training and validation set, respectively. The 70 CT scans from the source test set are treated as the test set.",
#   "url": "https://zenodo.org/record/5208230/files/organamnist.npz?download=1",
#   "MD5": "866b832ed4eeba67bfb9edee1d5544e6",
#   "task": "multi-class",
#   "label": {
#     "0": "bladder",
#     "1": "femur-left",
#     "2": "femur-right",
#     "3": "heart",
#     "4": "kidney-left",
#     "5": "kidney-right",
#     "6": "liver",
#     "7": "lung-left",
#     "8": "lung-right",
#     "9": "pancreas",
#     "10": "spleen"
#   },
#   "n_channels": 1,
#   "n_samples": {
#     "train": 34581,
#     "val": 6491,
#     "test": 17778
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                   [-1, 11]           1,419
# ================================================================
# Total params: 235,195
# Trainable params: 235,195
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.90
# Estimated Total Size (MB): 1.72
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|█████████████████████████████████████████| 271/271 [00:06<00:00, 38.95it/s]
# train -- accuracy: 0.72
# val -- accuracy: 1.0,  AUC: 0.92
# ===================
# Epoch 1
# 100%|█████████████████████████████████████████| 271/271 [00:06<00:00, 38.81it/s]
# train -- accuracy: 0.93
# val -- accuracy: 1.0,  AUC: 0.95
# ===================
# Epoch 2
# 100%|█████████████████████████████████████████| 271/271 [00:06<00:00, 39.39it/s]
# train -- accuracy: 0.96
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 3
# 100%|█████████████████████████████████████████| 271/271 [00:07<00:00, 38.12it/s]
# train -- accuracy: 0.98
# val -- accuracy: 1.0,  AUC: 0.97
# ===================
# Epoch 4
# 100%|█████████████████████████████████████████| 271/271 [00:06<00:00, 39.22it/s]
# train -- accuracy: 0.98
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 5
# 100%|█████████████████████████████████████████| 271/271 [00:06<00:00, 39.17it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 6
# 100%|█████████████████████████████████████████| 271/271 [00:06<00:00, 40.27it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.97
# ===================
# Epoch 7
# 100%|█████████████████████████████████████████| 271/271 [00:06<00:00, 39.32it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 8
# 100%|█████████████████████████████████████████| 271/271 [00:06<00:00, 38.75it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 9
# 100%|█████████████████████████████████████████| 271/271 [00:06<00:00, 39.56it/s]
# train -- accuracy: 1.0
# val -- accuracy: 1.0,  AUC: 0.97
# ===================
# test -- accuracy: 0.99,  AUC: 0.87

# %% [markdown]
# ### OrganCMNIST

# %%
clf_base_organcmnist = run_classifier_pipeline("organcmnist", info_flags, organcmnist)
# Out:
# {
#   "python_class": "OrganCMNIST",
#   "description": "The OrganCMNIST is based on 3D computed tomography (CT) images from Liver Tumor Segmentation Benchmark (LiTS). It is renamed from OrganMNIST_Coronal (in MedMNIST v1) for simplicity. We use bounding-box annotations of 11 body organs from another study to obtain the organ labels. Hounsfield-Unit (HU) of the 3D images are transformed into gray-scale with an abdominal window. We crop 2D images from the center slices of the 3D bounding boxes in coronal views (planes). The images are resized into 1\u00d728\u00d728 to perform multi-class classification of 11 body organs. 115 and 16 CT scans from the source training set are used as training and validation set, respectively. The 70 CT scans from the source test set are treated as the test set.",
#   "url": "https://zenodo.org/record/5208230/files/organcmnist.npz?download=1",
#   "MD5": "0afa5834fb105f7705a7d93372119a21",
#   "task": "multi-class",
#   "label": {
#     "0": "bladder",
#     "1": "femur-left",
#     "2": "femur-right",
#     "3": "heart",
#     "4": "kidney-left",
#     "5": "kidney-right",
#     "6": "liver",
#     "7": "lung-left",
#     "8": "lung-right",
#     "9": "pancreas",
#     "10": "spleen"
#   },
#   "n_channels": 1,
#   "n_samples": {
#     "train": 13000,
#     "val": 2392,
#     "test": 8268
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                   [-1, 11]           1,419
# ================================================================
# Total params: 235,195
# Trainable params: 235,195
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.90
# Estimated Total Size (MB): 1.72
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|█████████████████████████████████████████| 102/102 [00:02<00:00, 39.99it/s]
# train -- accuracy: 0.49
# val -- accuracy: 0.99,  AUC: 0.81
# ===================
# Epoch 1
# 100%|█████████████████████████████████████████| 102/102 [00:02<00:00, 40.01it/s]
# train -- accuracy: 0.79
# val -- accuracy: 1.0,  AUC: 0.91
# ===================
# Epoch 2
# 100%|█████████████████████████████████████████| 102/102 [00:02<00:00, 39.97it/s]
# train -- accuracy: 0.88
# val -- accuracy: 1.0,  AUC: 0.93
# ===================
# Epoch 3
# 100%|█████████████████████████████████████████| 102/102 [00:02<00:00, 39.76it/s]
# train -- accuracy: 0.91
# val -- accuracy: 1.0,  AUC: 0.95
# ===================
# Epoch 4
# 100%|█████████████████████████████████████████| 102/102 [00:02<00:00, 38.62it/s]
# train -- accuracy: 0.93
# val -- accuracy: 1.0,  AUC: 0.94
# ===================
# Epoch 5
# 100%|█████████████████████████████████████████| 102/102 [00:02<00:00, 38.72it/s]
# train -- accuracy: 0.95
# val -- accuracy: 1.0,  AUC: 0.94
# ===================
# Epoch 6
# 100%|█████████████████████████████████████████| 102/102 [00:02<00:00, 39.30it/s]
# train -- accuracy: 0.96
# val -- accuracy: 1.0,  AUC: 0.94
# ===================
# Epoch 7
# 100%|█████████████████████████████████████████| 102/102 [00:02<00:00, 38.56it/s]
# train -- accuracy: 0.97
# val -- accuracy: 1.0,  AUC: 0.95
# ===================
# Epoch 8
# 100%|█████████████████████████████████████████| 102/102 [00:02<00:00, 38.37it/s]
# train -- accuracy: 0.97
# val -- accuracy: 1.0,  AUC: 0.95
# ===================
# Epoch 9
# 100%|█████████████████████████████████████████| 102/102 [00:02<00:00, 39.44it/s]
# train -- accuracy: 0.98
# val -- accuracy: 1.0,  AUC: 0.95
# ===================
# test -- accuracy: 0.99,  AUC: 0.87

# %% [markdown]
# ### OrganSMNIST

# %%
clf_base_organsmnist = run_classifier_pipeline("organsmnist", info_flags, organsmnist)
# Out:
# {
#   "python_class": "OrganSMNIST",
#   "description": "The OrganSMNIST is based on 3D computed tomography (CT) images from Liver Tumor Segmentation Benchmark (LiTS). It is renamed from OrganMNIST_Sagittal (in MedMNIST v1) for simplicity. We use bounding-box annotations of 11 body organs from another study to obtain the organ labels. Hounsfield-Unit (HU) of the 3D images are transformed into gray-scale with an abdominal window. We crop 2D images from the center slices of the 3D bounding boxes in sagittal views (planes). The images are resized into 1\u00d728\u00d728 to perform multi-class classification of 11 body organs. 115 and 16 CT scans from the source training set are used as training and validation set, respectively. The 70 CT scans from the source test set are treated as the test set.",
#   "url": "https://zenodo.org/record/5208230/files/organsmnist.npz?download=1",
#   "MD5": "e5c39f1af030238290b9557d9503af9d",
#   "task": "multi-class",
#   "label": {
#     "0": "bladder",
#     "1": "femur-left",
#     "2": "femur-right",
#     "3": "heart",
#     "4": "kidney-left",
#     "5": "kidney-right",
#     "6": "liver",
#     "7": "lung-left",
#     "8": "lung-right",
#     "9": "pancreas",
#     "10": "spleen"
#   },
#   "n_channels": 1,
#   "n_samples": {
#     "train": 13940,
#     "val": 2452,
#     "test": 8829
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                   [-1, 11]           1,419
# ================================================================
# Total params: 235,195
# Trainable params: 235,195
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.90
# Estimated Total Size (MB): 1.72
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|█████████████████████████████████████████| 109/109 [00:02<00:00, 39.37it/s]
# train -- accuracy: 0.36
# val -- accuracy: 0.95,  AUC: 0.66
# ===================
# Epoch 1
# 100%|█████████████████████████████████████████| 109/109 [00:02<00:00, 39.26it/s]
# train -- accuracy: 0.62
# val -- accuracy: 0.98,  AUC: 0.79
# ===================
# Epoch 2
# 100%|█████████████████████████████████████████| 109/109 [00:02<00:00, 39.55it/s]
# train -- accuracy: 0.71
# val -- accuracy: 0.98,  AUC: 0.77
# ===================
# Epoch 3
# 100%|█████████████████████████████████████████| 109/109 [00:02<00:00, 39.35it/s]
# train -- accuracy: 0.75
# val -- accuracy: 0.99,  AUC: 0.83
# ===================
# Epoch 4
# 100%|█████████████████████████████████████████| 109/109 [00:02<00:00, 38.36it/s]
# train -- accuracy: 0.79
# val -- accuracy: 0.99,  AUC: 0.82
# ===================
# Epoch 5
# 100%|█████████████████████████████████████████| 109/109 [00:02<00:00, 38.79it/s]
# train -- accuracy: 0.83
# val -- accuracy: 0.99,  AUC: 0.83
# ===================
# Epoch 6
# 100%|█████████████████████████████████████████| 109/109 [00:02<00:00, 38.68it/s]
# train -- accuracy: 0.86
# val -- accuracy: 0.99,  AUC: 0.83
# ===================
# Epoch 7
# 100%|█████████████████████████████████████████| 109/109 [00:02<00:00, 38.98it/s]
# train -- accuracy: 0.87
# val -- accuracy: 0.99,  AUC: 0.83
# ===================
# Epoch 8
# 100%|█████████████████████████████████████████| 109/109 [00:02<00:00, 38.15it/s]
# train -- accuracy: 0.89
# val -- accuracy: 0.99,  AUC: 0.84
# ===================
# Epoch 9
# 100%|█████████████████████████████████████████| 109/109 [00:02<00:00, 37.51it/s]
# train -- accuracy: 0.91
# val -- accuracy: 0.99,  AUC: 0.85
# ===================
# test -- accuracy: 0.96,  AUC: 0.71

# %% [markdown]
# ## 4. Training a Conditional Variational Autoencoder for Data Augmentation and Retraining the Classifier with an Augmented Dataset
#
# ### PathMNIST
#
# #### Training the Conditional VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["pathmnist"][0]["label"])
n_channels = info_flags["pathmnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 150
epochs = 200

# %%
# Retrieves the data loader
train_loader = pathmnist[3]
val_loader = pathmnist[5]
test_loader = pathmnist[4]

# Runs the conditional VAE
pathmnist_condVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, 
    n_classes=n_classes, 
    epochs=epochs, 
    name_dataset="pathmnist", 
    output_intermediary_info=False,
    model_type="CondVAE"
)
# Out:
# ===================
# Testing Conditional Variational Autoencoder:
# Clearing CUDA Pytorch Cache
# Model Output size: torch.Size([10, 3, 28, 28])
# Forward pass test:  True
# {'loss': tensor(27136.6523, grad_fn=<AddBackward0>), 'Reconstruction_Loss': tensor(27136.5625, grad_fn=<MseLossBackward0>), 'KLD': tensor(-17.9964, grad_fn=<NegBackward0>)}
# Loss test:  True
# Cuda device:  cuda
# ===================
# Training phase:
# Train epoch 1 -- average loss: 81.13540674710869
# Validation set loss: 64.946947
# Train epoch 2 -- average loss: 60.744219742964056
# Validation set loss: 55.282179
# Train epoch 3 -- average loss: 51.8224119300593
# Validation set loss: 49.756213
# Train epoch 4 -- average loss: 47.321602000602695
# Validation set loss: 44.354077
# Train epoch 5 -- average loss: 44.0658697264529
# Validation set loss: 42.053598
# Train epoch 6 -- average loss: 41.64451685184489
# Validation set loss: 40.233365
# Train epoch 7 -- average loss: 39.56699471541726
# Validation set loss: 40.153587
# Train epoch 8 -- average loss: 38.41947439620906
# Validation set loss: 37.664991
# Train epoch 9 -- average loss: 36.91077801903501
# Validation set loss: 36.282416
# Train epoch 10 -- average loss: 36.10105459236231
# Validation set loss: 35.581865
# Train epoch 11 -- average loss: 35.30281303314544
# Validation set loss: 34.691399
# Train epoch 12 -- average loss: 34.299721459652766
# Validation set loss: 33.679474
# Train epoch 13 -- average loss: 33.44517511257336
# Validation set loss: 33.599575
# Train epoch 14 -- average loss: 32.996635619786225
# Validation set loss: 32.498601
# Train epoch 15 -- average loss: 31.83434108166309
# Validation set loss: 31.739714
# Train epoch 16 -- average loss: 31.44814248078452
# Validation set loss: 31.837252
# Train epoch 17 -- average loss: 31.015352067133975
# Validation set loss: 30.599861
# Train epoch 18 -- average loss: 30.404354443883488
# Validation set loss: 30.11024
# Train epoch 19 -- average loss: 29.916767350440185
# Validation set loss: 29.718813
# Train epoch 20 -- average loss: 29.375767084602632
# Validation set loss: 29.619438
# Train epoch 21 -- average loss: 29.589543286003142
# Validation set loss: 29.140768
# Train epoch 22 -- average loss: 29.039759091289476
# Validation set loss: 29.415872
# Train epoch 23 -- average loss: 28.574472545459486
# Validation set loss: 28.802737
# Train epoch 24 -- average loss: 28.39170054693403
# Validation set loss: 28.883801
# Train epoch 25 -- average loss: 28.36114257733829
# Validation set loss: 28.834747
# Train epoch 26 -- average loss: 28.131950198356254
# Validation set loss: 28.138651
# Train epoch 27 -- average loss: 27.855054743359144
# Validation set loss: 27.904117
# Train epoch 28 -- average loss: 27.539735515412556
# Validation set loss: 28.707551
# Train epoch 29 -- average loss: 27.47758818442061
# Validation set loss: 28.252788
# Train epoch 30 -- average loss: 27.216427506370074
# Validation set loss: 27.808628
# Train epoch 31 -- average loss: 26.961807193329687
# Validation set loss: 27.635948
# Train epoch 32 -- average loss: 26.61171584161336
# Validation set loss: 26.905144
# Train epoch 33 -- average loss: 26.340148709775015
# Validation set loss: 27.698881
# Train epoch 34 -- average loss: 26.307862165022005
# Validation set loss: 26.592512
# Train epoch 35 -- average loss: 26.09927024927779
# Validation set loss: 26.728907
# Train epoch 36 -- average loss: 25.83713533087907
# Validation set loss: 26.581645
# Train epoch 37 -- average loss: 25.813647006001915
# Validation set loss: 26.862287
# Train epoch 38 -- average loss: 25.617159327293344
# Validation set loss: 26.135419
# Train epoch 39 -- average loss: 25.726892006832248
# Validation set loss: 26.396012
# Train epoch 40 -- average loss: 25.265518304787612
# Validation set loss: 25.946853
# Train epoch 41 -- average loss: 25.151051014390244
# Validation set loss: 25.666716
# Train epoch 42 -- average loss: 24.874592291449932
# Validation set loss: 25.643528
# Train epoch 43 -- average loss: 24.975315170461027
# Validation set loss: 25.326002
# Train epoch 44 -- average loss: 24.723951917801166
# Validation set loss: 25.403172
# Train epoch 45 -- average loss: 24.620358542085377
# Validation set loss: 25.290283
# Train epoch 46 -- average loss: 24.386580287967767
# Validation set loss: 25.350491
# Train epoch 47 -- average loss: 24.256755374633947
# Validation set loss: 25.256525
# Train epoch 48 -- average loss: 24.379406987044476
# Validation set loss: 25.902231
# Train epoch 49 -- average loss: 24.090048792478886
# Validation set loss: 24.737664
# Train epoch 50 -- average loss: 23.845765767147704
# Validation set loss: 24.865832
# Train epoch 51 -- average loss: 23.814805821475094
# Validation set loss: 24.922489
# Train epoch 52 -- average loss: 23.99508589813193
# Validation set loss: 24.918819
# Train epoch 53 -- average loss: 23.594638351588955
# Validation set loss: 24.329201
# Train epoch 54 -- average loss: 23.469468718195202
# Validation set loss: 28.881035
# Train epoch 55 -- average loss: 23.72288903520766
# Validation set loss: 24.294413
# Train epoch 56 -- average loss: 23.421537381574055
# Validation set loss: 24.537894
# Train epoch 57 -- average loss: 23.271801350757734
# Validation set loss: 24.236521
# Train epoch 58 -- average loss: 23.25019939952789
# Validation set loss: 24.485761
# Train epoch 59 -- average loss: 22.986178262789327
# Validation set loss: 24.599629
# Train epoch 60 -- average loss: 23.00863921860069
# Validation set loss: 24.031927
# Train epoch 61 -- average loss: 22.807250578459954
# Validation set loss: 24.129338
# Train epoch 62 -- average loss: 22.721001810760274
# Validation set loss: 23.993069
# Train epoch 63 -- average loss: 22.650357370890745
# Validation set loss: 24.134839
# Train epoch 64 -- average loss: 22.604066425304666
# Validation set loss: 23.851618
# Train epoch 65 -- average loss: 22.760153133406405
# Validation set loss: 23.773232
# Train epoch 66 -- average loss: 22.495320422240663
# Validation set loss: 23.875408
# Train epoch 67 -- average loss: 22.435365991987883
# Validation set loss: 23.746634
# Train epoch 68 -- average loss: 22.385744585610055
# Validation set loss: 23.907126
# Train epoch 69 -- average loss: 22.1611335103663
# Validation set loss: 24.037154
# Train epoch 70 -- average loss: 22.25176616024243
# Validation set loss: 24.005591
# Train epoch 71 -- average loss: 22.279620896901516
# Validation set loss: 23.844565
# Train epoch 72 -- average loss: 22.068003933855394
# Validation set loss: 23.526261
# Train epoch 73 -- average loss: 21.955777970625192
# Validation set loss: 23.420181
# Train epoch 74 -- average loss: 21.871067660041074
# Validation set loss: 23.223354
# Train epoch 75 -- average loss: 21.951691852198095
# Validation set loss: 23.725677
# Train epoch 76 -- average loss: 21.681762773644433
# Validation set loss: 23.087048
# Train epoch 77 -- average loss: 21.767917140514946
# Validation set loss: 23.844956
# Train epoch 78 -- average loss: 21.593539891377986
# Validation set loss: 23.179478
# Train epoch 79 -- average loss: 21.753184140812074
# Validation set loss: 23.115758
# Train epoch 80 -- average loss: 21.95311179920442
# Validation set loss: 23.194556
# Train epoch 81 -- average loss: 21.561905070672413
# Validation set loss: 22.971826
# Train epoch 82 -- average loss: 21.417868522428037
# Validation set loss: 22.866349
# Train epoch 83 -- average loss: 21.24775953244949
# Validation set loss: 22.95475
# Train epoch 84 -- average loss: 21.274840032224088
# Validation set loss: 22.92713
# Train epoch 85 -- average loss: 21.14338935863241
# Validation set loss: 22.844077
# Train epoch 86 -- average loss: 21.1115098086255
# Validation set loss: 22.829302
# Train epoch 87 -- average loss: 21.04012028932243
# Validation set loss: 22.737653
# Train epoch 88 -- average loss: 21.152265146110445
# Validation set loss: 22.613423
# Train epoch 89 -- average loss: 20.892406082305914
# Validation set loss: 22.700665
# Train epoch 90 -- average loss: 20.890721885748633
# Validation set loss: 22.802237
# Train epoch 91 -- average loss: 20.773295040665545
# Validation set loss: 22.736827
# Train epoch 92 -- average loss: 20.7779681768951
# Validation set loss: 22.783846
# Train epoch 93 -- average loss: 20.69535391148135
# Validation set loss: 22.863036
# ==/!\== EARLY STOPPING: no validation loss improvement over the past 5 epochs
# ===================
# Testing phase:
# Test set loss: 22.855626

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![pathmnist_condvae](assets/pathmnist_conditionalVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 4% generated data was added, with weights corresponding to the rarity of the class 

condVAE_pathmnist_loader = generate_augmented_dataset_condVAE(
    n_channels, n_classes, latent_dims,
    "trained_models/CondVAE/pathmnist/pathmnist_epoch101.pth", 
    pathmnist[0], 64, pathmnist[4], pathmnist[5], 4000,
    weighted_sampling=True
)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_condVAE_pathmnist = run_classifier_pipeline("pathmnist", info_flags, condVAE_pathmnist_loader)
# Out:
# {
#   "python_class": "PathMNIST",
#   "description": "The PathMNIST is based on a prior study for predicting survival from colorectal cancer histology slides, providing a dataset (NCT-CRC-HE-100K) of 100,000 non-overlapping image patches from hematoxylin & eosin stained histological images, and a test dataset (CRC-VAL-HE-7K) of 7,180 image patches from a different clinical center. The dataset is comprised of 9 types of tissues, resulting in a multi-class classification task. We resize the source images of 3\u00d7224\u00d7224 into 3\u00d728\u00d728, and split NCT-CRC-HE-100K into training and validation set with a ratio of 9:1. The CRC-VAL-HE-7K is treated as the test set.",
#   "url": "https://zenodo.org/record/5208230/files/pathmnist.npz?download=1",
#   "MD5": "a8b06965200029087d5bd730944a56c1",
#   "task": "multi-class",
#   "label": {
#     "0": "adipose",
#     "1": "background",
#     "2": "debris",
#     "3": "lymphocytes",
#     "4": "mucus",
#     "5": "smooth muscle",
#     "6": "normal colon mucosa",
#     "7": "cancer-associated stroma",
#     "8": "colorectal adenocarcinoma epithelium"
#   },
#   "n_channels": 3,
#   "n_samples": {
#     "train": 89996,
#     "val": 10004,
#     "test": 7180
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             448
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                    [-1, 9]           1,161
# ================================================================
# Total params: 235,225
# Trainable params: 235,225
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.90
# Estimated Total Size (MB): 1.73
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|██████████████████████████████████████| 1469/1469 [00:14<00:00, 101.22it/s]
# train -- accuracy: 0.72
# val -- accuracy: 0.97,  AUC: 0.73
# ===================
# Epoch 1
# 100%|██████████████████████████████████████| 1469/1469 [00:14<00:00, 102.90it/s]
# train -- accuracy: 0.86
# val -- accuracy: 0.99,  AUC: 0.84
# ===================
# Epoch 2
# 100%|██████████████████████████████████████| 1469/1469 [00:14<00:00, 100.86it/s]
# train -- accuracy: 0.89
# val -- accuracy: 0.99,  AUC: 0.91
# ===================
# Epoch 3
# 100%|██████████████████████████████████████| 1469/1469 [00:14<00:00, 102.11it/s]
# train -- accuracy: 0.91
# val -- accuracy: 0.99,  AUC: 0.9
# ===================
# Epoch 4
# 100%|██████████████████████████████████████| 1469/1469 [00:13<00:00, 105.05it/s]
# train -- accuracy: 0.92
# val -- accuracy: 0.99,  AUC: 0.88
# ===================
# Epoch 5
# 100%|██████████████████████████████████████| 1469/1469 [00:13<00:00, 105.17it/s]
# train -- accuracy: 0.93
# val -- accuracy: 0.99,  AUC: 0.91
# ===================
# Epoch 6
# 100%|██████████████████████████████████████| 1469/1469 [00:13<00:00, 104.99it/s]
# train -- accuracy: 0.94
# val -- accuracy: 0.99,  AUC: 0.9
# ===================
# Epoch 7
# 100%|██████████████████████████████████████| 1469/1469 [00:13<00:00, 105.44it/s]
# train -- accuracy: 0.94
# val -- accuracy: 1.0,  AUC: 0.92
# ===================
# Epoch 8
# 100%|██████████████████████████████████████| 1469/1469 [00:13<00:00, 105.32it/s]
# train -- accuracy: 0.95
# val -- accuracy: 1.0,  AUC: 0.94
# ===================
# Epoch 9
# 100%|██████████████████████████████████████| 1469/1469 [00:13<00:00, 105.14it/s]
# train -- accuracy: 0.95
# val -- accuracy: 1.0,  AUC: 0.94
# ===================
# test -- accuracy: 0.97,  AUC: 0.85

# %% [markdown]
# ### DermaMNIST
#
# #### Training the Conditional VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["dermamnist"][0]["label"])
n_channels = info_flags["dermamnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 100
epochs = 200

# %%
# Retrieves the data loader
train_loader = dermamnist[3]
val_loader = dermamnist[5]
test_loader = dermamnist[4]

# Runs the conditional VAE
dermamnist_condVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, 
    n_classes=n_classes, 
    epochs=epochs, 
    name_dataset="dermamnist", 
    output_intermediary_info=False,
    model_type="CondVAE"
)
# Out:
# ===================
# Testing Conditional Variational Autoencoder:
# Clearing CUDA Pytorch Cache
# Model Output size: torch.Size([10, 3, 28, 28])
# Forward pass test:  True
# {'loss': tensor(26364.9668, grad_fn=<AddBackward0>), 'Reconstruction_Loss': tensor(26364.9062, grad_fn=<MseLossBackward0>), 'KLD': tensor(-12.1619, grad_fn=<NegBackward0>)}
# Loss test:  True
# Cuda device:  cuda
# ===================
# Training phase:
# Train epoch 1 -- average loss: 174.68301829309084
# Validation set loss: 155.814159
# Train epoch 2 -- average loss: 71.30671476960539
# Validation set loss: 63.377477
# Train epoch 3 -- average loss: 49.35040545392108
# Validation set loss: 44.233846
# Train epoch 4 -- average loss: 40.33235507517036
# Validation set loss: 37.534705
# Train epoch 5 -- average loss: 33.999587779686834
# Validation set loss: 31.084393
# Train epoch 6 -- average loss: 30.18775417523325
# Validation set loss: 30.906405
# Train epoch 7 -- average loss: 28.102301367717104
# Validation set loss: 27.290548
# Train epoch 8 -- average loss: 25.157598330798667
# Validation set loss: 24.48725
# Train epoch 9 -- average loss: 25.5012815727799
# Validation set loss: 25.551766
# Train epoch 10 -- average loss: 24.33130840978218
# Validation set loss: 25.467333
# Train epoch 11 -- average loss: 22.443693914205216
# Validation set loss: 22.159338
# Train epoch 12 -- average loss: 20.725847464477486
# Validation set loss: 22.433017
# Train epoch 13 -- average loss: 19.61322093782334
# Validation set loss: 23.618338
# Train epoch 14 -- average loss: 19.91554574053179
# Validation set loss: 19.690098
# Train epoch 15 -- average loss: 17.219441273012702
# Validation set loss: 17.334535
# Train epoch 16 -- average loss: 16.351003436435217
# Validation set loss: 20.143163
# Train epoch 17 -- average loss: 15.850349113776849
# Validation set loss: 15.744203
# Train epoch 18 -- average loss: 15.150582885306658
# Validation set loss: 23.327967
# Train epoch 19 -- average loss: 15.114895794077574
# Validation set loss: 16.616791
# Train epoch 20 -- average loss: 14.2253271804925
# Validation set loss: 14.915923
# Train epoch 21 -- average loss: 13.559397947197892
# Validation set loss: 14.524853
# Train epoch 22 -- average loss: 13.73457684196384
# Validation set loss: 14.638216
# Train epoch 23 -- average loss: 12.535413125518454
# Validation set loss: 17.947176
# Train epoch 24 -- average loss: 13.5146667994394
# Validation set loss: 15.701358
# Train epoch 25 -- average loss: 12.781696243906763
# Validation set loss: 15.75925
# Train epoch 26 -- average loss: 12.08261341406919
# Validation set loss: 15.954652
# ==/!\== EARLY STOPPING: no validation loss improvement over the past 5 epochs
# ===================
# Testing phase:
# Test set loss: 16.374076

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![dermamnist_condvae](assets/dermamnist_conditionalVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 10% generated data was added, with weights corresponding to the rarity of the class 

condVAE_dermamnist_loader = generate_augmented_dataset_condVAE(
    n_channels, n_classes, latent_dims,
    "trained_models/CondVAE/dermamnist/dermamnist_epoch40.pth", 
    dermamnist[0], 128, dermamnist[4], dermamnist[5], len(dermamnist[0])//10,
    weighted_sampling=True)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_condVAE_dermamnist = run_classifier_pipeline("dermamnist", info_flags, condVAE_dermamnist_loader)
# Out:
# {
#   "python_class": "DermaMNIST",
#   "description": "The DermaMNIST is based on the HAM10000, a large collection of multi-source dermatoscopic images of common pigmented skin lesions. The dataset consists of 10,015 dermatoscopic images categorized as 7 different diseases, formulized as a multi-class classification task. We split the images into training, validation and test set with a ratio of 7:1:2. The source images of 3\u00d7600\u00d7450 are resized into 3\u00d728\u00d728.",
#   "url": "https://zenodo.org/record/5208230/files/dermamnist.npz?download=1",
#   "MD5": "0744692d530f8e62ec473284d019b0c7",
#   "task": "multi-class",
#   "label": {
#     "0": "actinic keratoses and intraepithelial carcinoma",
#     "1": "basal cell carcinoma",
#     "2": "benign keratosis-like lesions",
#     "3": "dermatofibroma",
#     "4": "melanoma",
#     "5": "melanocytic nevi",
#     "6": "vascular lesions"
#   },
#   "n_channels": 3,
#   "n_samples": {
#     "train": 7007,
#     "val": 1003,
#     "test": 2005
#   },
#   "license": "CC BY-NC 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             448
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                    [-1, 7]             903
# ================================================================
# Total params: 234,967
# Trainable params: 234,967
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.90
# Estimated Total Size (MB): 1.73
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|███████████████████████████████████████████| 61/61 [00:00<00:00, 72.26it/s]
# train -- accuracy: 0.36
# val -- accuracy: 0.85,  AUC: 0.47
# ===================
# Epoch 1
# 100%|███████████████████████████████████████████| 61/61 [00:00<00:00, 71.64it/s]
# train -- accuracy: 0.52
# val -- accuracy: 0.89,  AUC: 0.58
# ===================
# Epoch 2
# 100%|███████████████████████████████████████████| 61/61 [00:00<00:00, 72.05it/s]
# train -- accuracy: 0.6
# val -- accuracy: 0.85,  AUC: 0.46
# ===================
# Epoch 3
# 100%|███████████████████████████████████████████| 61/61 [00:00<00:00, 72.18it/s]
# train -- accuracy: 0.66
# val -- accuracy: 0.88,  AUC: 0.63
# ===================
# Epoch 4
# 100%|███████████████████████████████████████████| 61/61 [00:00<00:00, 72.40it/s]
# train -- accuracy: 0.73
# val -- accuracy: 0.9,  AUC: 0.54
# ===================
# Epoch 5
# 100%|███████████████████████████████████████████| 61/61 [00:00<00:00, 72.44it/s]
# train -- accuracy: 0.78
# val -- accuracy: 0.89,  AUC: 0.6
# ===================
# Epoch 6
# 100%|███████████████████████████████████████████| 61/61 [00:00<00:00, 72.98it/s]
# train -- accuracy: 0.82
# val -- accuracy: 0.9,  AUC: 0.67
# ===================
# Epoch 7
# 100%|███████████████████████████████████████████| 61/61 [00:00<00:00, 72.79it/s]
# train -- accuracy: 0.86
# val -- accuracy: 0.88,  AUC: 0.6
# ===================
# Epoch 8
# 100%|███████████████████████████████████████████| 61/61 [00:00<00:00, 72.28it/s]
# train -- accuracy: 0.89
# val -- accuracy: 0.89,  AUC: 0.63
# ===================
# Epoch 9
# 100%|███████████████████████████████████████████| 61/61 [00:00<00:00, 72.47it/s]
# train -- accuracy: 0.88
# val -- accuracy: 0.89,  AUC: 0.63
# ===================
# test -- accuracy: 0.89,  AUC: 0.64

# %% [markdown]
# ### OctMNIST
#
# #### Training the Conditional VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["octmnist"][0]["label"])
n_channels = info_flags["octmnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 100
epochs = 200

# %%
# Retrieves the data loader
train_loader = octmnist[3]
val_loader = octmnist[5]
test_loader = octmnist[4]

# Runs the conditional VAE
octmnist_condVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, 
    n_classes=n_classes, 
    epochs=epochs, 
    name_dataset="octmnist", 
    output_intermediary_info=False,
    model_type="CondVAE"
)
# Out:
# ===================
# Testing Conditional Variational Autoencoder:
# Clearing CUDA Pytorch Cache
# Model Output size: torch.Size([10, 1, 28, 28])
# Forward pass test:  True
# {'loss': tensor(8625.8330, grad_fn=<AddBackward0>), 'Reconstruction_Loss': tensor(8625.7676, grad_fn=<MseLossBackward0>), 'KLD': tensor(-13.1478, grad_fn=<NegBackward0>)}
# Loss test:  True
# Cuda device:  cuda
# ===================
# Training phase:
# Train epoch 1 -- average loss: 17.19294979821362
# Validation set loss: 7.265178
# Train epoch 2 -- average loss: 6.570273666845969
# Validation set loss: 4.768516
# Train epoch 3 -- average loss: 4.841348619092316
# Validation set loss: 3.690773
# Train epoch 4 -- average loss: 4.022363103235751
# Validation set loss: 4.038991
# Train epoch 5 -- average loss: 3.4035698319041066
# Validation set loss: 2.844243
# Train epoch 6 -- average loss: 3.0819733812808083
# Validation set loss: 2.792446
# Train epoch 7 -- average loss: 2.8324641290894763
# Validation set loss: 2.68468
# Train epoch 8 -- average loss: 2.682543690876728
# Validation set loss: 2.215217
# Train epoch 9 -- average loss: 2.526474002623796
# Validation set loss: 2.08211
# Train epoch 10 -- average loss: 2.3920553754828062
# Validation set loss: 2.058207
# Train epoch 11 -- average loss: 2.2490042399187056
# Validation set loss: 1.993975
# Train epoch 12 -- average loss: 2.1164094546947814
# Validation set loss: 1.894495
# Train epoch 13 -- average loss: 2.0584841766884954
# Validation set loss: 1.854667
# Train epoch 14 -- average loss: 1.9660057649328997
# Validation set loss: 1.723305
# Train epoch 15 -- average loss: 1.8949069992264702
# Validation set loss: 1.757394
# Train epoch 16 -- average loss: 1.8370300815490348
# Validation set loss: 1.649275
# Train epoch 17 -- average loss: 1.8046886447574753
# Validation set loss: 1.567496
# Train epoch 18 -- average loss: 1.7820451470082366
# Validation set loss: 1.651668
# Train epoch 19 -- average loss: 1.6905912284647968
# Validation set loss: 1.499728
# Train epoch 20 -- average loss: 1.649466170958618
# Validation set loss: 1.692595
# Train epoch 21 -- average loss: 1.6338669683884413
# Validation set loss: 1.484602
# Train epoch 22 -- average loss: 1.5920751669041058
# Validation set loss: 1.431053
# Train epoch 23 -- average loss: 1.5698210350938355
# Validation set loss: 1.603976
# Train epoch 24 -- average loss: 1.536816543595851
# Validation set loss: 1.540751
# Train epoch 25 -- average loss: 1.5023984242306438
# Validation set loss: 1.392708
# Train epoch 26 -- average loss: 1.4862920975427567
# Validation set loss: 1.388861
# Train epoch 27 -- average loss: 1.475385286075297
# Validation set loss: 1.362467
# Train epoch 28 -- average loss: 1.4412259958586684
# Validation set loss: 1.293056
# Train epoch 29 -- average loss: 1.407634852236477
# Validation set loss: 1.285762
# Train epoch 30 -- average loss: 1.394925004149867
# Validation set loss: 1.392841
# Train epoch 31 -- average loss: 1.3825558167433738
# Validation set loss: 1.33265
# Train epoch 32 -- average loss: 1.3500375870855974
# Validation set loss: 1.233984
# Train epoch 33 -- average loss: 1.3678106953719442
# Validation set loss: 1.223589
# Train epoch 34 -- average loss: 1.3242617522126714
# Validation set loss: 1.216783
# Train epoch 35 -- average loss: 1.3007403176804087
# Validation set loss: 1.25781
# Train epoch 36 -- average loss: 1.2885968205485532
# Validation set loss: 1.306031
# Train epoch 37 -- average loss: 1.2724178037959737
# Validation set loss: 1.297409
# Train epoch 38 -- average loss: 1.2809647544730054
# Validation set loss: 1.167364
# Train epoch 39 -- average loss: 1.2544610176621391
# Validation set loss: 1.184655
# Train epoch 40 -- average loss: 1.239645869630374
# Validation set loss: 1.147589
# Train epoch 41 -- average loss: 1.2295339911063556
# Validation set loss: 1.173929
# Train epoch 42 -- average loss: 1.2332250715489546
# Validation set loss: 1.220464
# Train epoch 43 -- average loss: 1.2019233880109117
# Validation set loss: 1.158122
# Train epoch 44 -- average loss: 1.2020365377307356
# Validation set loss: 1.217657
# Train epoch 45 -- average loss: 1.1831387370803106
# Validation set loss: 1.131963
# Train epoch 46 -- average loss: 1.177200228156536
# Validation set loss: 1.140329
# Train epoch 47 -- average loss: 1.1599265558918705
# Validation set loss: 1.118234
# Train epoch 48 -- average loss: 1.1636700112196188
# Validation set loss: 1.105441
# Train epoch 49 -- average loss: 1.1551507995048822
# Validation set loss: 1.125856
# Train epoch 50 -- average loss: 1.1426751198328307
# Validation set loss: 1.08142
# Train epoch 51 -- average loss: 1.1234541206325033
# Validation set loss: 1.075511
# Train epoch 52 -- average loss: 1.1235789403666216
# Validation set loss: 1.148793
# Train epoch 53 -- average loss: 1.1180345749010474
# Validation set loss: 1.070283
# Train epoch 54 -- average loss: 1.0987645320081667
# Validation set loss: 1.036354
# Train epoch 55 -- average loss: 1.103105572027067
# Validation set loss: 1.065207
# Train epoch 56 -- average loss: 1.0968586830812193
# Validation set loss: 1.05784
# Train epoch 57 -- average loss: 1.0863586124916507
# Validation set loss: 1.032812
# Train epoch 58 -- average loss: 1.076896055810862
# Validation set loss: 1.068731
# Train epoch 59 -- average loss: 1.0724005313733465
# Validation set loss: 1.047529
# Train epoch 60 -- average loss: 1.0764832988904043
# Validation set loss: 1.005303
# Train epoch 61 -- average loss: 1.0704627803738818
# Validation set loss: 1.043058
# Train epoch 62 -- average loss: 1.0586145419139739
# Validation set loss: 1.006261
# Train epoch 63 -- average loss: 1.0379942127311022
# Validation set loss: 1.023244
# Train epoch 64 -- average loss: 1.0373041813991668
# Validation set loss: 1.013758
# Train epoch 65 -- average loss: 1.0481744957191323
# Validation set loss: 1.036164
# ==/!\== EARLY STOPPING: no validation loss improvement over the past 5 epochs
# ===================
# Testing phase:
# Test set loss: 1.473565

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![octmnist_condvae](assets/octmnist_conditionalVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 4% generated data was added, with weights corresponding to the rarity of the class 

condVAE_octmnist_loader = generate_augmented_dataset_condVAE(
    n_channels, n_classes, latent_dims,
    "trained_models/CondVAE/octmnist/octmnist_epoch54.pth", 
    octmnist[0], 128, octmnist[4], octmnist[5], 4000,
    weighted_sampling=True)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_condVAE_octmnist = run_classifier_pipeline("octmnist", info_flags, condVAE_octmnist_loader)
# Out:
# {
#   "python_class": "OCTMNIST",
#   "description": "The OCTMNIST is based on a prior dataset of 109,309 valid optical coherence tomography (OCT) images for retinal diseases. The dataset is comprised of 4 diagnosis categories, leading to a multi-class classification task. We split the source training set with a ratio of 9:1 into training and validation set, and use its source validation set as the test set. The source images are gray-scale, and their sizes are (384\u22121,536)\u00d7(277\u2212512). We center-crop the images and resize them into 1\u00d728\u00d728.",
#   "url": "https://zenodo.org/record/5208230/files/octmnist.npz?download=1",
#   "MD5": "c68d92d5b585d8d81f7112f81e2d0842",
#   "task": "multi-class",
#   "label": {
#     "0": "choroidal neovascularization",
#     "1": "diabetic macular edema",
#     "2": "drusen",
#     "3": "normal"
#   },
#   "n_channels": 1,
#   "n_samples": {
#     "train": 97477,
#     "val": 10832,
#     "test": 1000
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                    [-1, 4]             516
# ================================================================
# Total params: 234,292
# Trainable params: 234,292
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.89
# Estimated Total Size (MB): 1.72
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|█████████████████████████████████████████| 793/793 [00:12<00:00, 61.83it/s]
# train -- accuracy: 0.72
# val -- accuracy: 0.94,  AUC: 0.81
# ===================
# Epoch 1
# 100%|█████████████████████████████████████████| 793/793 [00:12<00:00, 64.54it/s]
# train -- accuracy: 0.82
# val -- accuracy: 0.95,  AUC: 0.82
# ===================
# Epoch 2
# 100%|█████████████████████████████████████████| 793/793 [00:12<00:00, 62.56it/s]
# train -- accuracy: 0.85
# val -- accuracy: 0.96,  AUC: 0.74
# ===================
# Epoch 3
# 100%|█████████████████████████████████████████| 793/793 [00:12<00:00, 63.89it/s]
# train -- accuracy: 0.88
# val -- accuracy: 0.96,  AUC: 0.86
# ===================
# Epoch 4
# 100%|█████████████████████████████████████████| 793/793 [00:12<00:00, 61.09it/s]
# train -- accuracy: 0.89
# val -- accuracy: 0.97,  AUC: 0.89
# ===================
# Epoch 5
# 100%|█████████████████████████████████████████| 793/793 [00:12<00:00, 61.48it/s]
# train -- accuracy: 0.9
# val -- accuracy: 0.96,  AUC: 0.85
# ===================
# Epoch 6
# 100%|█████████████████████████████████████████| 793/793 [00:12<00:00, 62.03it/s]
# train -- accuracy: 0.92
# val -- accuracy: 0.97,  AUC: 0.91
# ===================
# Epoch 7
# 100%|█████████████████████████████████████████| 793/793 [00:12<00:00, 63.39it/s]
# train -- accuracy: 0.93
# val -- accuracy: 0.97,  AUC: 0.9
# ===================
# Epoch 8
# 100%|█████████████████████████████████████████| 793/793 [00:12<00:00, 62.97it/s]
# train -- accuracy: 0.94
# val -- accuracy: 0.97,  AUC: 0.86
# ===================
# Epoch 9
# 100%|█████████████████████████████████████████| 793/793 [00:12<00:00, 61.81it/s]
# train -- accuracy: 0.94
# val -- accuracy: 0.97,  AUC: 0.89
# ===================
# test -- accuracy: 0.93,  AUC: 0.71

# %% [markdown]
# ### PneumoniaMNIST
#
# #### Training the Conditional VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["pneumoniamnist"][0]["label"])
n_channels = info_flags["pneumoniamnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 150
epochs = 200

# %%
# Retrieves the data loader
train_loader = pneumoniamnist[3]
val_loader = pneumoniamnist[5]
test_loader = pneumoniamnist[4]

# Runs the conditional VAE
pneumoniamnist_condVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, 
    n_classes=n_classes, 
    epochs=epochs, 
    name_dataset="pneumoniamnist", 
    output_intermediary_info=False,
    model_type="CondVAE"
)
# Out:
# ===================
# Testing Conditional Variational Autoencoder:
# Clearing CUDA Pytorch Cache
# Model Output size: torch.Size([10, 1, 28, 28])
# Forward pass test:  True
# {'loss': tensor(8371.5391, grad_fn=<AddBackward0>), 'Reconstruction_Loss': tensor(8371.4434, grad_fn=<MseLossBackward0>), 'KLD': tensor(-19.0912, grad_fn=<NegBackward0>)}
# Loss test:  True
# Cuda device:  cuda
# ===================
# Training phase:
# Train epoch 1 -- average loss: 49.528974119849195
# Validation set loss: 30.622793
# Train epoch 2 -- average loss: 28.237484163010436
# Validation set loss: 24.829663
# Train epoch 3 -- average loss: 20.4147206373709
# Validation set loss: 18.111246
# Train epoch 4 -- average loss: 15.345664465943939
# Validation set loss: 13.577257
# Train epoch 5 -- average loss: 12.164803815272874
# Validation set loss: 10.660208
# Train epoch 6 -- average loss: 10.473185886846524
# Validation set loss: 9.818214
# Train epoch 7 -- average loss: 9.344983382050831
# Validation set loss: 9.275686
# Train epoch 8 -- average loss: 8.478795961495061
# Validation set loss: 8.104193
# Train epoch 9 -- average loss: 8.289739150158308
# Validation set loss: 7.791453
# Train epoch 10 -- average loss: 7.885117095713911
# Validation set loss: 8.183922
# Train epoch 11 -- average loss: 7.329506912166624
# Validation set loss: 7.475397
# Train epoch 12 -- average loss: 6.910508887486227
# Validation set loss: 6.813219
# Train epoch 13 -- average loss: 7.053313807096133
# Validation set loss: 6.833124
# Train epoch 14 -- average loss: 6.616943255661905
# Validation set loss: 6.409948
# Train epoch 15 -- average loss: 6.3893973092052425
# Validation set loss: 6.223391
# Train epoch 16 -- average loss: 5.985431901256007
# Validation set loss: 6.077944
# Train epoch 17 -- average loss: 6.5474054017305985
# Validation set loss: 6.522815
# Train epoch 18 -- average loss: 6.139831154044645
# Validation set loss: 5.532651
# Train epoch 19 -- average loss: 5.573848857247637
# Validation set loss: 5.531433
# Train epoch 20 -- average loss: 5.558849545384021
# Validation set loss: 5.582413
# Train epoch 21 -- average loss: 5.357807804389636
# Validation set loss: 5.280409
# Train epoch 22 -- average loss: 5.186697993120503
# Validation set loss: 5.843588
# Train epoch 23 -- average loss: 5.286413784237767
# Validation set loss: 5.620893
# Train epoch 24 -- average loss: 5.280272555938695
# Validation set loss: 5.098724
# Train epoch 25 -- average loss: 5.053415173682097
# Validation set loss: 5.253901
# Train epoch 26 -- average loss: 5.1622352632508
# Validation set loss: 5.488587
# Train epoch 27 -- average loss: 5.071990629729317
# Validation set loss: 5.148264
# Train epoch 28 -- average loss: 5.218901926719646
# Validation set loss: 5.451642
# Train epoch 29 -- average loss: 4.855127514472125
# Validation set loss: 4.858184
# Train epoch 30 -- average loss: 4.852944606628677
# Validation set loss: 5.512844
# Train epoch 31 -- average loss: 4.660638399213274
# Validation set loss: 4.635512
# Train epoch 32 -- average loss: 4.536826951278907
# Validation set loss: 4.816357
# Train epoch 33 -- average loss: 4.717322518892377
# Validation set loss: 4.825953
# Train epoch 34 -- average loss: 4.640072429595403
# Validation set loss: 4.994056
# Train epoch 35 -- average loss: 4.455474250683262
# Validation set loss: 4.603379
# Train epoch 36 -- average loss: 4.259031653910648
# Validation set loss: 4.77109
# Train epoch 37 -- average loss: 4.471393847728849
# Validation set loss: 4.960791
# Train epoch 38 -- average loss: 4.628629874048744
# Validation set loss: 4.67101
# Train epoch 39 -- average loss: 4.398145398550755
# Validation set loss: 4.61381
# Train epoch 40 -- average loss: 4.52625356980472
# Validation set loss: 5.261866
# ==/!\== EARLY STOPPING: no validation loss improvement over the past 5 epochs
# ===================
# Testing phase:
# Test set loss: 5.733136

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![pneumoniamnist_condvae](assets/pneumonia_conditionalVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 10% generated data was added, with weights corresponding to the rarity of the class 

condVAE_pneumoniamnist_loader = generate_augmented_dataset_condVAE(
    n_channels, n_classes, latent_dims,
    "trained_models/CondVAE/pneumoniamnist/pneumoniamnist_epoch33.pth", 
    pneumoniamnist[0], 128, pneumoniamnist[4], pneumoniamnist[5], len(pneumoniamnist[0])//10,
    weighted_sampling=True)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_condVAE_pneumoniamnist = run_classifier_pipeline("pneumoniamnist", info_flags, condVAE_pneumoniamnist_loader)
# Out:
# {
#   "python_class": "PneumoniaMNIST",
#   "description": "The PneumoniaMNIST is based on a prior dataset of 5,856 pediatric chest X-Ray images. The task is binary-class classification of pneumonia against normal. We split the source training set with a ratio of 9:1 into training and validation set and use its source validation set as the test set. The source images are gray-scale, and their sizes are (384\u22122,916)\u00d7(127\u22122,713). We center-crop the images and resize them into 1\u00d728\u00d728.",
#   "url": "https://zenodo.org/record/5208230/files/pneumoniamnist.npz?download=1",
#   "MD5": "28209eda62fecd6e6a2d98b1501bb15f",
#   "task": "binary-class",
#   "label": {
#     "0": "normal",
#     "1": "pneumonia"
#   },
#   "n_channels": 1,
#   "n_samples": {
#     "train": 4708,
#     "val": 524,
#     "test": 624
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                    [-1, 2]             258
# ================================================================
# Total params: 234,034
# Trainable params: 234,034
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.89
# Estimated Total Size (MB): 1.72
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|███████████████████████████████████████████| 41/41 [00:00<00:00, 63.83it/s]
# train -- accuracy: 0.86
# val -- accuracy: 0.99,  AUC: 0.89
# ===================
# Epoch 1
# 100%|███████████████████████████████████████████| 41/41 [00:00<00:00, 64.01it/s]
# train -- accuracy: 0.95
# val -- accuracy: 0.99,  AUC: 0.96
# ===================
# Epoch 2
# 100%|███████████████████████████████████████████| 41/41 [00:00<00:00, 63.68it/s]
# train -- accuracy: 0.97
# val -- accuracy: 0.99,  AUC: 0.97
# ===================
# Epoch 3
# 100%|███████████████████████████████████████████| 41/41 [00:00<00:00, 63.10it/s]
# train -- accuracy: 0.97
# val -- accuracy: 1.0,  AUC: 0.97
# ===================
# Epoch 4
# 100%|███████████████████████████████████████████| 41/41 [00:00<00:00, 62.96it/s]
# train -- accuracy: 0.99
# val -- accuracy: 0.99,  AUC: 0.95
# ===================
# Epoch 5
# 100%|███████████████████████████████████████████| 41/41 [00:00<00:00, 64.47it/s]
# train -- accuracy: 0.98
# val -- accuracy: 1.0,  AUC: 0.98
# ===================
# Epoch 6
# 100%|███████████████████████████████████████████| 41/41 [00:00<00:00, 64.61it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 7
# 100%|███████████████████████████████████████████| 41/41 [00:00<00:00, 63.96it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 8
# 100%|███████████████████████████████████████████| 41/41 [00:00<00:00, 64.44it/s]
# train -- accuracy: 1.0
# val -- accuracy: 1.0,  AUC: 0.97
# ===================
# Epoch 9
# 100%|███████████████████████████████████████████| 41/41 [00:00<00:00, 62.41it/s]
# train -- accuracy: 1.0
# val -- accuracy: 1.0,  AUC: 0.98
# ===================
# test -- accuracy: 0.96,  AUC: 0.86

# %% [markdown]
# ### BreastMNIST
#
# #### Training the Conditional VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["breastmnist"][0]["label"])
n_channels = info_flags["breastmnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 150
epochs = 200

# %%
# Retrieves the data loader
train_loader = breastmnist[3]
val_loader = breastmnist[5]
test_loader = breastmnist[4]

# Runs the conditional VAE
breastmnist_condVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, 
    n_classes=n_classes, 
    epochs=epochs, 
    name_dataset="breastmnist", 
    output_intermediary_info=False,
    model_type="CondVAE"
)
# Out:
# ===================
# Testing Conditional Variational Autoencoder:
# Clearing CUDA Pytorch Cache
# Model Output size: torch.Size([10, 1, 28, 28])
# Forward pass test:  True
# {'loss': tensor(9402.2979, grad_fn=<AddBackward0>), 'Reconstruction_Loss': tensor(9402.2051, grad_fn=<MseLossBackward0>), 'KLD': tensor(-18.5098, grad_fn=<NegBackward0>)}
# Loss test:  True
# Cuda device:  cuda
# ===================
# Training phase:
# Train epoch 1 -- average loss: 255.71328768887363
# Validation set loss: 187.097431
# Train epoch 2 -- average loss: 79.59832383599473
# Validation set loss: 134.522887
# Train epoch 3 -- average loss: 64.79563283396291
# Validation set loss: 177.309257
# Train epoch 4 -- average loss: 59.38478485219208
# Validation set loss: 197.284743
# Train epoch 5 -- average loss: 58.16799066005609
# Validation set loss: 129.552759
# Train epoch 6 -- average loss: 60.067934811770265
# Validation set loss: 65.216778
# Train epoch 7 -- average loss: 48.8980478140024
# Validation set loss: 49.67401
# Train epoch 8 -- average loss: 46.84733184702667
# Validation set loss: 51.650535
# Train epoch 9 -- average loss: 44.54697940812443
# Validation set loss: 52.074998
# Train epoch 10 -- average loss: 44.117676004822
# Validation set loss: 54.839587
# Train epoch 11 -- average loss: 40.81545651614011
# Validation set loss: 52.276968
# Train epoch 12 -- average loss: 39.73214576357887
# Validation set loss: 46.240532
# Train epoch 13 -- average loss: 38.398484673692195
# Validation set loss: 44.56085
# Train epoch 14 -- average loss: 38.549393538590316
# Validation set loss: 46.534483
# Train epoch 15 -- average loss: 36.4184324383299
# Validation set loss: 41.636963
# Train epoch 16 -- average loss: 35.63581797840831
# Validation set loss: 39.586056
# Train epoch 17 -- average loss: 37.063329004979394
# Validation set loss: 43.416144
# Train epoch 18 -- average loss: 34.1715327112666
# Validation set loss: 36.502285
# Train epoch 19 -- average loss: 33.93264804043613
# Validation set loss: 37.736187
# Train epoch 20 -- average loss: 33.803704230339974
# Validation set loss: 36.5057
# Train epoch 21 -- average loss: 33.267720540364586
# Validation set loss: 33.968299
# Train epoch 22 -- average loss: 32.436763777400984
# Validation set loss: 38.183738
# Train epoch 23 -- average loss: 31.00062980232658
# Validation set loss: 33.154122
# Train epoch 24 -- average loss: 31.700925945798993
# Validation set loss: 37.370944
# Train epoch 25 -- average loss: 31.020934164305746
# Validation set loss: 37.439763
# Train epoch 26 -- average loss: 30.795315361721613
# Validation set loss: 32.260251
# Train epoch 27 -- average loss: 31.133074749957075
# Validation set loss: 31.275938
# Train epoch 28 -- average loss: 30.435849144345237
# Validation set loss: 31.030752
# Train epoch 29 -- average loss: 29.497732756338714
# Validation set loss: 31.380481
# Train epoch 30 -- average loss: 27.285239865928343
# Validation set loss: 30.24821
# Train epoch 31 -- average loss: 28.261353433350504
# Validation set loss: 30.46891
# Train epoch 32 -- average loss: 27.318035419170673
# Validation set loss: 29.065195
# Train epoch 33 -- average loss: 27.62728311727335
# Validation set loss: 31.38845
# Train epoch 34 -- average loss: 25.318096566112924
# Validation set loss: 28.174395
# Train epoch 35 -- average loss: 25.390543619791668
# Validation set loss: 30.602332
# Train epoch 36 -- average loss: 26.220895285134787
# Validation set loss: 28.455153
# Train epoch 37 -- average loss: 25.21900856101906
# Validation set loss: 33.897893
# Train epoch 38 -- average loss: 24.603555197244162
# Validation set loss: 28.643977
# Train epoch 39 -- average loss: 24.835274609017286
# Validation set loss: 32.799748
# ==/!\== EARLY STOPPING: no validation loss improvement over the past 5 epochs
# ===================
# Testing phase:
# Test set loss: 32.789764

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![breastmnist_condvae](assets/breastmnist_conditionalVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 10% generated data was added, with weights corresponding to the rarity of the class 

condVAE_breastmnist_loader = generate_augmented_dataset_condVAE(
    n_channels, n_classes, latent_dims,
    "trained_models/CondVAE/breastmnist/breastmnist_epoch58.pth", 
    breastmnist[0], 128, breastmnist[4], breastmnist[5], len(breastmnist[0])//30,
    weighted_sampling=True)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_condVAE_breastmnist = run_classifier_pipeline("breastmnist", info_flags, condVAE_breastmnist_loader)
# Out:
# {
#   "python_class": "BreastMNIST",
#   "description": "The BreastMNIST is based on a dataset of 780 breast ultrasound images. It is categorized into 3 classes: normal, benign, and malignant. As we use low-resolution images, we simplify the task into binary classification by combining normal and benign as positive and classifying them against malignant as negative. We split the source dataset with a ratio of 7:1:2 into training, validation and test set. The source images of 1\u00d7500\u00d7500 are resized into 1\u00d728\u00d728.",
#   "url": "https://zenodo.org/record/5208230/files/breastmnist.npz?download=1",
#   "MD5": "750601b1f35ba3300ea97c75c52ff8f6",
#   "task": "binary-class",
#   "label": {
#     "0": "malignant",
#     "1": "normal, benign"
#   },
#   "n_channels": 1,
#   "n_samples": {
#     "train": 546,
#     "val": 78,
#     "test": 156
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                    [-1, 2]             258
# ================================================================
# Total params: 234,034
# Trainable params: 234,034
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.89
# Estimated Total Size (MB): 1.72
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 59.29it/s]
# train -- accuracy: 0.52
# val -- accuracy: 0.71,  AUC: 0.27
# ===================
# Epoch 1
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 68.39it/s]
# train -- accuracy: 0.6
# val -- accuracy: 0.71,  AUC: 0.27
# ===================
# Epoch 2
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 64.94it/s]
# train -- accuracy: 0.68
# val -- accuracy: 0.72,  AUC: 0.27
# ===================
# Epoch 3
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 68.99it/s]
# train -- accuracy: 0.71
# val -- accuracy: 0.73,  AUC: 0.27
# ===================
# Epoch 4
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 65.09it/s]
# train -- accuracy: 0.77
# val -- accuracy: 0.74,  AUC: 0.37
# ===================
# Epoch 5
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 59.40it/s]
# train -- accuracy: 0.79
# val -- accuracy: 0.76,  AUC: 0.37
# ===================
# Epoch 6
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 59.92it/s]
# train -- accuracy: 0.83
# val -- accuracy: 0.77,  AUC: 0.41
# ===================
# Epoch 7
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 59.15it/s]
# train -- accuracy: 0.82
# val -- accuracy: 0.81,  AUC: 0.41
# ===================
# Epoch 8
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 60.31it/s]
# train -- accuracy: 0.83
# val -- accuracy: 0.86,  AUC: 0.56
# ===================
# Epoch 9
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00, 64.04it/s]
# train -- accuracy: 0.87
# val -- accuracy: 0.84,  AUC: 0.72
# ===================
# test -- accuracy: 0.79,  AUC: 0.71

# %% [markdown]
# ### OrganAMNIST
#
# #### Training the Conditional VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["organamnist"][0]["label"])
n_channels = info_flags["organamnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 150
epochs = 200

# %%
# Retrieves the data loader
train_loader = organamnist[3]
val_loader = organamnist[5]
test_loader = organamnist[4]

# Runs the conditional VAE
organamnist_condVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, 
    n_classes=n_classes, 
    epochs=epochs, 
    name_dataset="organamnist", 
    output_intermediary_info=False,
    model_type="CondVAE"
)
# Out:
# ===================
# Testing Conditional Variational Autoencoder:
# Clearing CUDA Pytorch Cache
# Model Output size: torch.Size([10, 1, 28, 28])
# Forward pass test:  True
# {'loss': tensor(8683.8262, grad_fn=<AddBackward0>), 'Reconstruction_Loss': tensor(8683.7266, grad_fn=<MseLossBackward0>), 'KLD': tensor(-19.9087, grad_fn=<NegBackward0>)}
# Loss test:  True
# Cuda device:  cuda
# ===================
# Training phase:
# Train epoch 1 -- average loss: 112.46566423786952
# Validation set loss: 89.091303
# Train epoch 2 -- average loss: 70.9238394915425
# Validation set loss: 75.632856
# Train epoch 3 -- average loss: 59.13425090065376
# Validation set loss: 67.663184
# Train epoch 4 -- average loss: 53.00167211018153
# Validation set loss: 63.142944
# Train epoch 5 -- average loss: 48.928119901999786
# Validation set loss: 61.385421
# Train epoch 6 -- average loss: 46.04968753798261
# Validation set loss: 59.751656
# Train epoch 7 -- average loss: 44.34367079426067
# Validation set loss: 59.584576
# Train epoch 8 -- average loss: 42.60529990565911
# Validation set loss: 59.443801
# Train epoch 9 -- average loss: 41.18654135392437
# Validation set loss: 57.517539
# Train epoch 10 -- average loss: 39.989407935580594
# Validation set loss: 57.921799
# Train epoch 11 -- average loss: 38.86764705249033
# Validation set loss: 56.659212
# Train epoch 12 -- average loss: 37.736941965949846
# Validation set loss: 56.074056
# Train epoch 13 -- average loss: 36.91013370400405
# Validation set loss: 57.305087
# Train epoch 14 -- average loss: 36.031797300786444
# Validation set loss: 55.423557
# Train epoch 15 -- average loss: 35.48034747569847
# Validation set loss: 55.824835
# Train epoch 16 -- average loss: 34.76683342937709
# Validation set loss: 54.99851
# Train epoch 17 -- average loss: 34.071513253430915
# Validation set loss: 56.127937
# Train epoch 18 -- average loss: 33.5899122281236
# Validation set loss: 54.524288
# Train epoch 19 -- average loss: 33.1300557074954
# Validation set loss: 55.698127
# Train epoch 20 -- average loss: 32.61284295153216
# Validation set loss: 55.202244
# Train epoch 21 -- average loss: 32.242591397026864
# Validation set loss: 55.786855
# Train epoch 22 -- average loss: 31.710595938927806
# Validation set loss: 54.202336
# Train epoch 23 -- average loss: 31.292984883783387
# Validation set loss: 54.617627
# Train epoch 24 -- average loss: 31.046621743196116
# Validation set loss: 54.379739
# Train epoch 25 -- average loss: 30.623654649675537
# Validation set loss: 55.456639
# Train epoch 26 -- average loss: 30.371305111210816
# Validation set loss: 55.430083
# Train epoch 27 -- average loss: 30.01632693694921
# Validation set loss: 54.490216
# ==/!\== EARLY STOPPING: no validation loss improvement over the past 5 epochs
# ===================
# Testing phase:
# Test set loss: 52.591454

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![organamnist_condvae](assets/organamnist_conditionalVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 10% generated data was added, with weights corresponding to the rarity of the class 

condVAE_organamnist_loader = generate_augmented_dataset_condVAE(
    n_channels, n_classes, latent_dims,
    "trained_models/CondVAE/organamnist/organamnist_epoch29.pth", 
    organamnist[0], 128, organamnist[4], organamnist[5], len(organamnist[0])//10,
    weighted_sampling=True)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_condVAE_organamnist = run_classifier_pipeline("organamnist", info_flags, condVAE_organamnist_loader)
# Out:
# {
#   "python_class": "OrganAMNIST",
#   "description": "The OrganAMNIST is based on 3D computed tomography (CT) images from Liver Tumor Segmentation Benchmark (LiTS). It is renamed from OrganMNIST_Axial (in MedMNIST v1) for simplicity. We use bounding-box annotations of 11 body organs from another study to obtain the organ labels. Hounsfield-Unit (HU) of the 3D images are transformed into gray-scale with an abdominal window. We crop 2D images from the center slices of the 3D bounding boxes in axial views (planes). The images are resized into 1\u00d728\u00d728 to perform multi-class classification of 11 body organs. 115 and 16 CT scans from the source training set are used as training and validation set, respectively. The 70 CT scans from the source test set are treated as the test set.",
#   "url": "https://zenodo.org/record/5208230/files/organamnist.npz?download=1",
#   "MD5": "866b832ed4eeba67bfb9edee1d5544e6",
#   "task": "multi-class",
#   "label": {
#     "0": "bladder",
#     "1": "femur-left",
#     "2": "femur-right",
#     "3": "heart",
#     "4": "kidney-left",
#     "5": "kidney-right",
#     "6": "liver",
#     "7": "lung-left",
#     "8": "lung-right",
#     "9": "pancreas",
#     "10": "spleen"
#   },
#   "n_channels": 1,
#   "n_samples": {
#     "train": 34581,
#     "val": 6491,
#     "test": 17778
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                   [-1, 11]           1,419
# ================================================================
# Total params: 235,195
# Trainable params: 235,195
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.90
# Estimated Total Size (MB): 1.72
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|█████████████████████████████████████████| 298/298 [00:04<00:00, 67.12it/s]
# train -- accuracy: 0.72
# val -- accuracy: 1.0,  AUC: 0.94
# ===================
# Epoch 1
# 100%|█████████████████████████████████████████| 298/298 [00:04<00:00, 67.54it/s]
# train -- accuracy: 0.91
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 2
# 100%|█████████████████████████████████████████| 298/298 [00:04<00:00, 66.35it/s]
# train -- accuracy: 0.95
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 3
# 100%|█████████████████████████████████████████| 298/298 [00:04<00:00, 67.83it/s]
# train -- accuracy: 0.97
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 4
# 100%|█████████████████████████████████████████| 298/298 [00:04<00:00, 66.45it/s]
# train -- accuracy: 0.97
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 5
# 100%|█████████████████████████████████████████| 298/298 [00:04<00:00, 65.92it/s]
# train -- accuracy: 0.98
# val -- accuracy: 1.0,  AUC: 0.97
# ===================
# Epoch 6
# 100%|█████████████████████████████████████████| 298/298 [00:04<00:00, 66.58it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 7
# 100%|█████████████████████████████████████████| 298/298 [00:04<00:00, 68.25it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.97
# ===================
# Epoch 8
# 100%|█████████████████████████████████████████| 298/298 [00:04<00:00, 71.30it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 9
# 100%|█████████████████████████████████████████| 298/298 [00:04<00:00, 67.37it/s]
# train -- accuracy: 0.99
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# test -- accuracy: 0.99,  AUC: 0.87

# %% [markdown]
# ### OrganCMNIST
#
# #### Training the Conditional VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["organcmnist"][0]["label"])
n_channels = info_flags["organcmnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 150
epochs = 200

# %%
# Retrieves the data loader
train_loader = organcmnist[3]
val_loader = organcmnist[5]
test_loader = organcmnist[4]

# Runs the conditional VAE
organcmnist_condVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, 
    n_classes=n_classes, 
    epochs=epochs, 
    name_dataset="organcmnist", 
    output_intermediary_info=False,
    model_type="CondVAE"
)
# Out:
# ===================
# Testing Conditional Variational Autoencoder:
# Clearing CUDA Pytorch Cache
# Model Output size: torch.Size([10, 1, 28, 28])
# Forward pass test:  True
# {'loss': tensor(10111.4756, grad_fn=<AddBackward0>), 'Reconstruction_Loss': tensor(10111.3809, grad_fn=<MseLossBackward0>), 'KLD': tensor(-18.9830, grad_fn=<NegBackward0>)}
# Loss test:  True
# Cuda device:  cuda
# ===================
# Training phase:
# Train epoch 1 -- average loss: 144.2680283203125
# Validation set loss: 114.869819
# Train epoch 2 -- average loss: 91.3274365234375
# Validation set loss: 89.440528
# Train epoch 3 -- average loss: 75.96778891225962
# Validation set loss: 79.011666
# Train epoch 4 -- average loss: 67.35061842698317
# Validation set loss: 74.131092
# Train epoch 5 -- average loss: 62.30435862379808
# Validation set loss: 73.912358
# Train epoch 6 -- average loss: 59.27879341947116
# Validation set loss: 70.054631
# Train epoch 7 -- average loss: 55.33933715820312
# Validation set loss: 65.819208
# Train epoch 8 -- average loss: 54.312615966796876
# Validation set loss: 63.215716
# Train epoch 9 -- average loss: 51.55989610877404
# Validation set loss: 60.983222
# Train epoch 10 -- average loss: 50.38739590219351
# Validation set loss: 67.017168
# Train epoch 11 -- average loss: 48.63128294020433
# Validation set loss: 60.156658
# Train epoch 12 -- average loss: 48.38501156850962
# Validation set loss: 58.946007
# Train epoch 13 -- average loss: 46.257491661658655
# Validation set loss: 58.22875
# Train epoch 14 -- average loss: 45.30843635441707
# Validation set loss: 57.135568
# Train epoch 15 -- average loss: 43.93426573768029
# Validation set loss: 56.549716
# Train epoch 16 -- average loss: 43.78091768704928
# Validation set loss: 56.700605
# Train epoch 17 -- average loss: 42.855793588491586
# Validation set loss: 55.52909
# Train epoch 18 -- average loss: 41.27197044020433
# Validation set loss: 56.517777
# Train epoch 19 -- average loss: 41.26221593299279
# Validation set loss: 55.007859
# Train epoch 20 -- average loss: 39.48048555814303
# Validation set loss: 55.959541
# Train epoch 21 -- average loss: 39.80899308894231
# Validation set loss: 54.227562
# Train epoch 22 -- average loss: 38.79606862229567
# Validation set loss: 54.907777
# Train epoch 23 -- average loss: 38.48242559344952
# Validation set loss: 54.728237
# Train epoch 24 -- average loss: 38.07500129582332
# Validation set loss: 54.457812
# Train epoch 25 -- average loss: 37.17417578125
# Validation set loss: 54.542672
# Train epoch 26 -- average loss: 37.11500159630409
# Validation set loss: 53.775564
# Train epoch 27 -- average loss: 36.390721942608174
# Validation set loss: 53.10214
# Train epoch 28 -- average loss: 35.6460112492488
# Validation set loss: 53.98986
# Train epoch 29 -- average loss: 35.17572791466346
# Validation set loss: 54.14649
# Train epoch 30 -- average loss: 34.969076303335335
# Validation set loss: 53.226104
# Train epoch 31 -- average loss: 34.27462640850361
# Validation set loss: 54.6625
# Train epoch 32 -- average loss: 34.393080265925484
# Validation set loss: 54.954945
# ==/!\== EARLY STOPPING: no validation loss improvement over the past 5 epochs
# ===================
# Testing phase:
# Test set loss: 47.938906

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![organcmnist_condvae](assets/organcmnist_conditionalVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 10% generated data was added, with weights corresponding to the rarity of the class 

condVAE_organcmnist_loader = generate_augmented_dataset_condVAE(
    n_channels, n_classes, latent_dims,
    "trained_models/CondVAE/organcmnist/organcmnist_epoch26.pth", 
    organcmnist[0], 128, organcmnist[4], organcmnist[5], len(organcmnist[0])//10,
    weighted_sampling=True)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_condVAE_organcmnist = run_classifier_pipeline("organcmnist", info_flags, condVAE_organcmnist_loader)
# Out:
# {
#   "python_class": "OrganCMNIST",
#   "description": "The OrganCMNIST is based on 3D computed tomography (CT) images from Liver Tumor Segmentation Benchmark (LiTS). It is renamed from OrganMNIST_Coronal (in MedMNIST v1) for simplicity. We use bounding-box annotations of 11 body organs from another study to obtain the organ labels. Hounsfield-Unit (HU) of the 3D images are transformed into gray-scale with an abdominal window. We crop 2D images from the center slices of the 3D bounding boxes in coronal views (planes). The images are resized into 1\u00d728\u00d728 to perform multi-class classification of 11 body organs. 115 and 16 CT scans from the source training set are used as training and validation set, respectively. The 70 CT scans from the source test set are treated as the test set.",
#   "url": "https://zenodo.org/record/5208230/files/organcmnist.npz?download=1",
#   "MD5": "0afa5834fb105f7705a7d93372119a21",
#   "task": "multi-class",
#   "label": {
#     "0": "bladder",
#     "1": "femur-left",
#     "2": "femur-right",
#     "3": "heart",
#     "4": "kidney-left",
#     "5": "kidney-right",
#     "6": "liver",
#     "7": "lung-left",
#     "8": "lung-right",
#     "9": "pancreas",
#     "10": "spleen"
#   },
#   "n_channels": 1,
#   "n_samples": {
#     "train": 13000,
#     "val": 2392,
#     "test": 8268
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                   [-1, 11]           1,419
# ================================================================
# Total params: 235,195
# Trainable params: 235,195
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.90
# Estimated Total Size (MB): 1.72
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|█████████████████████████████████████████| 112/112 [00:01<00:00, 67.19it/s]
# train -- accuracy: 0.52
# val -- accuracy: 0.99,  AUC: 0.85
# ===================
# Epoch 1
# 100%|█████████████████████████████████████████| 112/112 [00:01<00:00, 69.26it/s]
# train -- accuracy: 0.79
# val -- accuracy: 1.0,  AUC: 0.93
# ===================
# Epoch 2
# 100%|█████████████████████████████████████████| 112/112 [00:01<00:00, 65.89it/s]
# train -- accuracy: 0.85
# val -- accuracy: 1.0,  AUC: 0.94
# ===================
# Epoch 3
# 100%|█████████████████████████████████████████| 112/112 [00:01<00:00, 69.80it/s]
# train -- accuracy: 0.89
# val -- accuracy: 1.0,  AUC: 0.94
# ===================
# Epoch 4
# 100%|█████████████████████████████████████████| 112/112 [00:01<00:00, 68.08it/s]
# train -- accuracy: 0.91
# val -- accuracy: 1.0,  AUC: 0.94
# ===================
# Epoch 5
# 100%|█████████████████████████████████████████| 112/112 [00:01<00:00, 66.91it/s]
# train -- accuracy: 0.92
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# Epoch 6
# 100%|█████████████████████████████████████████| 112/112 [00:01<00:00, 68.39it/s]
# train -- accuracy: 0.94
# val -- accuracy: 1.0,  AUC: 0.95
# ===================
# Epoch 7
# 100%|█████████████████████████████████████████| 112/112 [00:01<00:00, 70.19it/s]
# train -- accuracy: 0.95
# val -- accuracy: 1.0,  AUC: 0.94
# ===================
# Epoch 8
# 100%|█████████████████████████████████████████| 112/112 [00:01<00:00, 68.72it/s]
# train -- accuracy: 0.96
# val -- accuracy: 1.0,  AUC: 0.95
# ===================
# Epoch 9
# 100%|█████████████████████████████████████████| 112/112 [00:01<00:00, 69.31it/s]
# train -- accuracy: 0.96
# val -- accuracy: 1.0,  AUC: 0.96
# ===================
# test -- accuracy: 0.98,  AUC: 0.85

# %% [markdown]
# ### OrganSMNIST
#
# #### Training the Conditional VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["organsmnist"][0]["label"])
n_channels = info_flags["organsmnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 150
epochs = 200

# %%
# Retrieves the data loader
train_loader = organsmnist[3]
val_loader = organsmnist[5]
test_loader = organsmnist[4]

# Runs the conditional VAE
organsmnist_condVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, 
    n_classes=n_classes, 
    epochs=epochs, 
    name_dataset="organsmnist", 
    output_intermediary_info=False,
    model_type="CondVAE"
)
# Out:
# ===================
# Testing Conditional Variational Autoencoder:
# Clearing CUDA Pytorch Cache
# Model Output size: torch.Size([10, 1, 28, 28])
# Forward pass test:  True
# {'loss': tensor(8764.6123, grad_fn=<AddBackward0>), 'Reconstruction_Loss': tensor(8764.5195, grad_fn=<MseLossBackward0>), 'KLD': tensor(-18.6463, grad_fn=<NegBackward0>)}
# Loss test:  True
# Cuda device:  cuda
# ===================
# Training phase:
# Train epoch 1 -- average loss: 150.61059829514886
# Validation set loss: 115.935521
# Train epoch 2 -- average loss: 97.81899126838235
# Validation set loss: 94.443139
# Train epoch 3 -- average loss: 83.1094891891589
# Validation set loss: 82.814012
# Train epoch 4 -- average loss: 73.18965176509819
# Validation set loss: 74.434504
# Train epoch 5 -- average loss: 66.0186279997422
# Validation set loss: 70.559662
# Train epoch 6 -- average loss: 63.007186210993545
# Validation set loss: 67.796127
# Train epoch 7 -- average loss: 58.74541565554385
# Validation set loss: 64.591751
# Train epoch 8 -- average loss: 55.832805669666875
# Validation set loss: 63.037478
# Train epoch 9 -- average loss: 53.44293284696691
# Validation set loss: 62.036819
# Train epoch 10 -- average loss: 51.89288699616661
# Validation set loss: 59.528689
# Train epoch 11 -- average loss: 49.6690321803264
# Validation set loss: 59.339133
# Train epoch 12 -- average loss: 49.02670765333573
# Validation set loss: 58.136457
# Train epoch 13 -- average loss: 48.063405807254306
# Validation set loss: 57.099361
# Train epoch 14 -- average loss: 46.207785528940995
# Validation set loss: 56.692417
# Train epoch 15 -- average loss: 45.28938261494575
# Validation set loss: 56.910106
# Train epoch 16 -- average loss: 44.6652969688733
# Validation set loss: 56.44778
# Train epoch 17 -- average loss: 43.50455008770848
# Validation set loss: 55.684331
# Train epoch 18 -- average loss: 42.737285737704
# Validation set loss: 54.69299
# Train epoch 19 -- average loss: 41.33087345599444
# Validation set loss: 54.38108
# Train epoch 20 -- average loss: 40.74136337652439
# Validation set loss: 55.326158
# Train epoch 21 -- average loss: 40.5658281936536
# Validation set loss: 54.10392
# Train epoch 22 -- average loss: 39.636826669263364
# Validation set loss: 52.908792
# Train epoch 23 -- average loss: 38.820410646632894
# Validation set loss: 53.451561
# Train epoch 24 -- average loss: 38.256335571814475
# Validation set loss: 53.232757
# Train epoch 25 -- average loss: 37.64467580787078
# Validation set loss: 53.121987
# Train epoch 26 -- average loss: 37.24760090678802
# Validation set loss: 52.867619
# Train epoch 27 -- average loss: 36.90550426773225
# Validation set loss: 53.146918
# Train epoch 28 -- average loss: 36.69973365203551
# Validation set loss: 53.368687
# Train epoch 29 -- average loss: 37.409523743639035
# Validation set loss: 52.281685
# Train epoch 30 -- average loss: 35.72340744653425
# Validation set loss: 53.094123
# Train epoch 31 -- average loss: 35.098584895086084
# Validation set loss: 52.144591
# Train epoch 32 -- average loss: 34.468408343234394
# Validation set loss: 51.860557
# Train epoch 33 -- average loss: 34.09452750207362
# Validation set loss: 53.630044
# Train epoch 34 -- average loss: 33.949270362799275
# Validation set loss: 52.857541
# Train epoch 35 -- average loss: 33.658102649048374
# Validation set loss: 51.936873
# Train epoch 36 -- average loss: 33.624458319555906
# Validation set loss: 52.431644
# Train epoch 37 -- average loss: 33.05307506851349
# Validation set loss: 51.78087
# Train epoch 38 -- average loss: 32.691389454385984
# Validation set loss: 51.90959
# Train epoch 39 -- average loss: 32.65493127283783
# Validation set loss: 52.242699
# Train epoch 40 -- average loss: 32.1694728068676
# Validation set loss: 52.190734
# Train epoch 41 -- average loss: 32.01033213983478
# Validation set loss: 52.490889
# Train epoch 42 -- average loss: 31.662000947840074
# Validation set loss: 52.341728
# ==/!\== EARLY STOPPING: no validation loss improvement over the past 5 epochs
# ===================
# Testing phase:
# Test set loss: 46.83345

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![organsmnist_condvae](assets/organsmnist_conditionalVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 10% generated data was added, with weights corresponding to the rarity of the class 

condVAE_organsmnist_loader = generate_augmented_dataset_condVAE(
    n_channels, n_classes, latent_dims,
    "trained_models/CondVAE/organsmnist/organsmnist_epoch24.pth", 
    organsmnist[0], 128, organsmnist[4], organsmnist[5], len(organsmnist[0])//10,
    weighted_sampling=True)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_condVAE_organsmnist = run_classifier_pipeline("organsmnist", info_flags, condVAE_organsmnist_loader)
# Out:
# {
#   "python_class": "OrganSMNIST",
#   "description": "The OrganSMNIST is based on 3D computed tomography (CT) images from Liver Tumor Segmentation Benchmark (LiTS). It is renamed from OrganMNIST_Sagittal (in MedMNIST v1) for simplicity. We use bounding-box annotations of 11 body organs from another study to obtain the organ labels. Hounsfield-Unit (HU) of the 3D images are transformed into gray-scale with an abdominal window. We crop 2D images from the center slices of the 3D bounding boxes in sagittal views (planes). The images are resized into 1\u00d728\u00d728 to perform multi-class classification of 11 body organs. 115 and 16 CT scans from the source training set are used as training and validation set, respectively. The 70 CT scans from the source test set are treated as the test set.",
#   "url": "https://zenodo.org/record/5208230/files/organsmnist.npz?download=1",
#   "MD5": "e5c39f1af030238290b9557d9503af9d",
#   "task": "multi-class",
#   "label": {
#     "0": "bladder",
#     "1": "femur-left",
#     "2": "femur-right",
#     "3": "heart",
#     "4": "kidney-left",
#     "5": "kidney-right",
#     "6": "liver",
#     "7": "lung-left",
#     "8": "lung-right",
#     "9": "pancreas",
#     "10": "spleen"
#   },
#   "n_channels": 1,
#   "n_samples": {
#     "train": 13940,
#     "val": 2452,
#     "test": 8829
#   },
#   "license": "CC BY 4.0"
# }
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 26, 26]             160
#        BatchNorm2d-2           [-1, 16, 26, 26]              32
#               ReLU-3           [-1, 16, 26, 26]               0
#             Conv2d-4           [-1, 16, 24, 24]           2,320
#        BatchNorm2d-5           [-1, 16, 24, 24]              32
#               ReLU-6           [-1, 16, 24, 24]               0
#          MaxPool2d-7           [-1, 16, 12, 12]               0
#             Conv2d-8           [-1, 64, 10, 10]           9,280
#        BatchNorm2d-9           [-1, 64, 10, 10]             128
#              ReLU-10           [-1, 64, 10, 10]               0
#            Conv2d-11             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-12             [-1, 64, 8, 8]             128
#              ReLU-13             [-1, 64, 8, 8]               0
#            Conv2d-14             [-1, 64, 8, 8]          36,928
#       BatchNorm2d-15             [-1, 64, 8, 8]             128
#              ReLU-16             [-1, 64, 8, 8]               0
#         MaxPool2d-17             [-1, 64, 4, 4]               0
#            Linear-18                  [-1, 128]         131,200
#              ReLU-19                  [-1, 128]               0
#            Linear-20                  [-1, 128]          16,512
#              ReLU-21                  [-1, 128]               0
#            Linear-22                   [-1, 11]           1,419
# ================================================================
# Total params: 235,195
# Trainable params: 235,195
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.90
# Estimated Total Size (MB): 1.72
# ----------------------------------------------------------------
# None
# ===================
# Epoch 0
# 100%|█████████████████████████████████████████| 120/120 [00:01<00:00, 67.48it/s]
# train -- accuracy: 0.38
# val -- accuracy: 0.97,  AUC: 0.71
# ===================
# Epoch 1
# 100%|█████████████████████████████████████████| 120/120 [00:01<00:00, 69.72it/s]
# train -- accuracy: 0.62
# val -- accuracy: 0.98,  AUC: 0.75
# ===================
# Epoch 2
# 100%|█████████████████████████████████████████| 120/120 [00:01<00:00, 69.27it/s]
# train -- accuracy: 0.69
# val -- accuracy: 0.99,  AUC: 0.8
# ===================
# Epoch 3
# 100%|█████████████████████████████████████████| 120/120 [00:01<00:00, 68.16it/s]
# train -- accuracy: 0.74
# val -- accuracy: 0.99,  AUC: 0.82
# ===================
# Epoch 4
# 100%|█████████████████████████████████████████| 120/120 [00:01<00:00, 69.40it/s]
# train -- accuracy: 0.77
# val -- accuracy: 0.99,  AUC: 0.79
# ===================
# Epoch 5
# 100%|█████████████████████████████████████████| 120/120 [00:01<00:00, 68.28it/s]
# train -- accuracy: 0.79
# val -- accuracy: 0.99,  AUC: 0.82
# ===================
# Epoch 6
# 100%|█████████████████████████████████████████| 120/120 [00:01<00:00, 67.92it/s]
# train -- accuracy: 0.83
# val -- accuracy: 0.99,  AUC: 0.85
# ===================
# Epoch 7
# 100%|█████████████████████████████████████████| 120/120 [00:01<00:00, 69.13it/s]
# train -- accuracy: 0.84
# val -- accuracy: 0.99,  AUC: 0.84
# ===================
# Epoch 8
# 100%|█████████████████████████████████████████| 120/120 [00:01<00:00, 69.54it/s]
# train -- accuracy: 0.86
# val -- accuracy: 0.99,  AUC: 0.84
# ===================
# Epoch 9
# 100%|█████████████████████████████████████████| 120/120 [00:01<00:00, 69.51it/s]
# train -- accuracy: 0.89
# val -- accuracy: 0.99,  AUC: 0.84
# ===================
# test -- accuracy: 0.96,  AUC: 0.71

# %% [markdown]
# ## 5. Training a Joint Variational Autoencoder for Data Augmentation and Retraining the Classifier with an Augmented Dataset
#
# ### PathMNIST
#
# #### Training the Joint VAE

# %%
# Retrieves the dataset parameters
n_channels = info_flags["pathmnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 100
categorical_dims = 50
epochs = 200

# %%
# Retrieves the data loader
train_loader = pathmnist[3]
val_loader = pathmnist[5]
test_loader = pathmnist[4]

# Runs the Joint VAE
pathmnist_jointVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, categorical_dims=categorical_dims,
    epochs=epochs, 
    name_dataset="pathmnist", 
    output_intermediary_info=False,
    model_type="JointVAE"
)
# Out:
# ===================
# Testing Joint Variational Autoencoder:
# Clearing CUDA Pytorch Cache
# Model Output size: torch.Size([10, 3, 28, 28])
# Forward pass test:  True
# {'loss': tensor(805671.1250, grad_fn=<AddBackward0>), 'Reconstruction_Loss': tensor(26855.6426, grad_fn=<MseLossBackward0>), 'Capacity_Loss': tensor(378.6323, grad_fn=<AddBackward0>)}
# Loss test:  True
# Cuda device:  cuda
# ===================
# Training phase:
# Train epoch 1 -- average loss: 2438.814382527244
# Validation set loss: 2745.741385
# Train epoch 2 -- average loss: 1766.2077850812466
# Validation set loss: 1606.74001
# Train epoch 3 -- average loss: 1544.6557215151402
# Validation set loss: 1520.861579
# Train epoch 4 -- average loss: 1431.0077424665055
# Validation set loss: 1384.245071
# Train epoch 5 -- average loss: 1348.5809824837702
# Validation set loss: 1312.203459
# Train epoch 6 -- average loss: 1283.85167094666
# Validation set loss: 1240.739393
# Train epoch 7 -- average loss: 1226.991060627
# Validation set loss: 1231.345304
# Train epoch 8 -- average loss: 1185.7361057626867
# Validation set loss: 1184.621254
# Train epoch 9 -- average loss: 1143.7664698292147
# Validation set loss: 1286.245524
# Train epoch 10 -- average loss: 1115.8973361272654
# Validation set loss: 1095.205399
# Train epoch 11 -- average loss: 1083.056266367915
# Validation set loss: 1106.052032
# Train epoch 12 -- average loss: 1064.5772046682978
# Validation set loss: 1084.46283
# Train epoch 13 -- average loss: 1040.4075034194227
# Validation set loss: 1069.834813
# Train epoch 14 -- average loss: 1024.051746331955
# Validation set loss: 1024.966238
# Train epoch 15 -- average loss: 1005.5498802333923
# Validation set loss: 1005.835552
# Train epoch 16 -- average loss: 988.8377754506103
# Validation set loss: 983.164968
# Train epoch 17 -- average loss: 979.7381226057963
# Validation set loss: 975.372561
# Train epoch 18 -- average loss: 961.5787246143232
# Validation set loss: 970.583386

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![pathmnist_jointae](assets/pathmnist_jointVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 4% generated data was added, with weights corresponding to the rarity of the class 

jointVAE_pathmnist_loader = generate_augmented_dataset_jointVAE(
    n_channels, latent_dims, categorical_dims,
    "trained_models/JointVAE/pathmnist/pathmnist_epoch35.pth", 
    pathmnist[0], 64, pathmnist[4], pathmnist[5], 4000
)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_jointVAE_pathmnist = run_classifier_pipeline("pathmnist", info_flags, jointVAE_pathmnist_loader)

# %% [markdown]
# ### DermaMNIST
#
# #### Training the Joint VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["dermamnist"][0]["label"])
n_channels = info_flags["dermamnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 100
categorical_dims = 50
epochs = 200

# %%
# Retrieves the data loader
train_loader = dermamnist[3]
val_loader = dermamnist[5]
test_loader = dermamnist[4]

# Runs the Joint VAE
dermamnist_jointVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, categorical_dims=categorical_dims,
    epochs=epochs, 
    name_dataset="dermamnist", 
    output_intermediary_info=False,
    model_type="JointVAE"
)

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![dermamnist_jointvae](assets/dermamnist_jointVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 10% generated data was added, with weights corresponding to the rarity of the class 

jointVAE_dermamnist_loader = generate_augmented_dataset_jointVAE(
    n_channels, latent_dims, categorical_dims,
    "trained_models/JointVAE/dermamnist/dermamnist_epoch42.pth", 
    dermamnist[0], 128, dermamnist[4], dermamnist[5], len(dermamnist[0])//10)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_jointVAE_dermamnist = run_classifier_pipeline("dermamnist", info_flags, jointVAE_dermamnist_loader)

# %% [markdown]
# ### OctMNIST
#
# #### Training the Joint VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["octmnist"][0]["label"])
n_channels = info_flags["octmnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 75
categorical_dims = 25
epochs = 200

# %%
# Retrieves the data loader
train_loader = octmnist[3]
val_loader = octmnist[5]
test_loader = octmnist[4]

# Runs the Joint VAE
octmnist_jointVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, categorical_dims=categorical_dims,
    epochs=epochs, 
    name_dataset="octmnist", 
    output_intermediary_info=False,
    model_type="JointVAE"
)

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![octmnist_jointvae](assets/octmnist_jointVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 4% generated data was added, with weights corresponding to the rarity of the class 

jointVAE_octmnist_loader = generate_augmented_dataset_jointVAE(
    n_channels, latent_dims, categorical_dims,
    "trained_models/JointVAE/octmnist/octmnist_epoch45.pth", 
    octmnist[0], 128, octmnist[4], octmnist[5], 4000,
)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_jointVAE_octmnist = run_classifier_pipeline("octmnist", info_flags, jointVAE_octmnist_loader)

# %% [markdown]
# ### PneumoniaMNIST
#
# #### Training the Joint VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["pneumoniamnist"][0]["label"])
n_channels = info_flags["pneumoniamnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 100
categorical_dims = 50
epochs = 200

# %%
# Retrieves the data loader
train_loader = pneumoniamnist[3]
val_loader = pneumoniamnist[5]
test_loader = pneumoniamnist[4]

# Runs the Joint VAE
pneumoniamnist_jointVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, categorical_dims=categorical_dims,
    epochs=epochs, 
    name_dataset="pneumoniamnist", 
    output_intermediary_info=False,
    model_type="JointVAE"
)

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![pneumoniamnist_jointvae](assets/pneumonia_jointVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 10% generated data was added, with weights corresponding to the rarity of the class 

jointVAE_pneumoniamnist_loader = generate_augmented_dataset_jointVAE(
    n_channels, latent_dims, categorical_dims,
    "trained_models/JointVAE/pneumoniamnist/pneumoniamnist_epoch27.pth", 
    pneumoniamnist[0], 128, pneumoniamnist[4], pneumoniamnist[5], len(pneumoniamnist[0])//10,)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_jointVAE_pneumoniamnist = run_classifier_pipeline("pneumoniamnist", info_flags, jointVAE_pneumoniamnist_loader)

# %% [markdown]
# ### BreastMNIST
#
# #### Training the Joint VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["breastmnist"][0]["label"])
n_channels = info_flags["breastmnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 100
categorical_dims = 50
epochs = 200

# %%
# Retrieves the data loader
train_loader = breastmnist[3]
val_loader = breastmnist[5]
test_loader = breastmnist[4]

# Runs the Joint VAE
breastmnist_jointVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, categorical_dims=categorical_dims,
    epochs=epochs, 
    name_dataset="breastmnist", 
    output_intermediary_info=False,
    model_type="JointVAE"
)

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![breastmnist_jointvae](assets/breastmnist_jointVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 10% generated data was added, with weights corresponding to the rarity of the class 

jointVAE_breastmnist_loader = generate_augmented_dataset_jointVAE(
    n_channels, latent_dims, categorical_dims,
    "trained_models/JointVAE/breastmnist/breastmnist_epoch22.pth", 
    breastmnist[0], 128, breastmnist[4], breastmnist[5], len(breastmnist[0])//30,
)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_jointVAE_breastmnist = run_classifier_pipeline("breastmnist", info_flags, jointVAE_breastmnist_loader)

# %% [markdown]
# ### OrganAMNIST
#
# #### Training the Joint VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["organamnist"][0]["label"])
n_channels = info_flags["organamnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 100
categorical_dims = 50
epochs = 200

# %%
# Retrieves the data loader
train_loader = organamnist[3]
val_loader = organamnist[5]
test_loader = organamnist[4]

# Runs the Joint VAE
organamnist_jointVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, categorical_dims=categorical_dims,
    epochs=epochs, 
    name_dataset="organamnist", 
    output_intermediary_info=False,
    model_type="JointVAE"
)

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![organamnist_jointvae](assets/organamnist_jointVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 10% generated data was added, with weights corresponding to the rarity of the class 

jointVAE_organamnist_loader = generate_augmented_dataset_jointVAE(
    n_channels, latent_dims, categorical_dims,
    "trained_models/JointVAE/organamnist/organamnist_epoch32.pth", 
    organamnist[0], 128, organamnist[4], organamnist[5], len(organamnist[0])//10,
)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_jointVAE_organamnist = run_classifier_pipeline("organamnist", info_flags, jointVAE_organamnist_loader)

# %% [markdown]
# ### OrganCMNIST
#
# #### Training the Joint VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["organcmnist"][0]["label"])
n_channels = info_flags["organcmnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 100
categorical_dims = 50
epochs = 200

# %%
# Retrieves the data loader
train_loader = organcmnist[3]
val_loader = organcmnist[5]
test_loader = organcmnist[4]

# Runs the Joint VAE
organcmnist_jointVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, categorical_dims=categorical_dims, 
    epochs=epochs, 
    name_dataset="organcmnist", 
    output_intermediary_info=False,
    model_type="JointVAE"
)

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![organcmnist_jointvae](assets/organcmnist_jointVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 10% generated data was added, with weights corresponding to the rarity of the class 

jointVAE_organcmnist_loader = generate_augmented_dataset_jointVAE(
    n_channels, latent_dims, categorical_dims,
    "trained_models/JointVAE/organcmnist/organcmnist_epoch36.pth", 
    organcmnist[0], 128, organcmnist[4], organcmnist[5], len(organcmnist[0])//10,
)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_jointVAE_organcmnist = run_classifier_pipeline("organcmnist", info_flags, jointVAE_organcmnist_loader)

# %% [markdown]
# ### OrganSMNIST
#
# #### Training the Joint VAE

# %%
# Retrieves the dataset parameters
n_classes  = len(info_flags["organsmnist"][0]["label"])
n_channels = info_flags["organsmnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 100
categorical_dims = 50
epochs = 200

# %%
# Retrieves the data loader
train_loader = organsmnist[3]
val_loader = organsmnist[5]
test_loader = organsmnist[4]

# Runs the Joint VAE
organsmnist_jointVAE_model, training_losses, validation_losses, test_loss = run_encoder_pipeline(
    train_loader, val_loader, test_loader,  
    n_channels, latent_dims, categorical_dims=categorical_dims,
    epochs=epochs, 
    name_dataset="organsmnist", 
    output_intermediary_info=False,
    model_type="JointVAE"
)

# %% [markdown]
# <u>Output (to avoid rerunning the cell):</u>
#
# ![organsmnist_jointvae](assets/organsmnist_jointVAE.png)

# %% [markdown]
# #### Generating an upgraded dataset

# %%
# Creates a new data loader with the augmented data added to the already existing data
# 10% generated data was added, with weights corresponding to the rarity of the class 

jointVAE_organsmnist_loader = generate_augmented_dataset_jointVAE(
    n_channels, latent_dims, categorical_dims,
    "trained_models/JointVAE/organsmnist/organsmnist_epoch28.pth", 
    organsmnist[0], 128, organsmnist[4], organsmnist[5], len(organsmnist[0])//10,
)

# %% [markdown]
# #### Retraining the classifier and assessing changes in performance

# %%
# Runs the classifier again 

clf_jointVAE_organsmnist = run_classifier_pipeline("organsmnist", info_flags, jointVAE_organsmnist_loader)

# %%
from python_scripts.classifier import run_classifier_pipeline
from python_scripts.variational_autoencoders import run_encoder_pipeline, one_hot
from python_scripts.data import retrieve_flag_info, import_dataset
from python_scripts.data import check_cuda_availability
from python_scripts.data import generate_augmented_dataset_condVAE
from python_scripts.data import generate_augmented_dataset_jointVAE

import warnings
warnings.filterwarnings('ignore')

data_flags = ["pathmnist", "dermamnist", "octmnist", "pneumoniamnist", 
              "breastmnist", "organamnist", "organcmnist", "organsmnist"]

info_flags = {flag:retrieve_flag_info(flag) for flag in data_flags}

from python_scripts.generative_adversarial_networks import ConditionalDiscriminator, ConditionalGenerator
from python_scripts.generative_adversarial_networks import run_GAN_pipeline, Discriminator, Generator
from torchsummary import summary

pneumoniamnist = import_dataset("pneumoniamnist", info_flags, 8)# Retrieves the data loader

train_loader = pneumoniamnist[3]
val_loader = pneumoniamnist[5]
test_loader = pneumoniamnist[4]

# Retrieves the dataset parameters
n_classes  = len(info_flags["pneumoniamnist"][0]["label"])
n_channels = info_flags["pneumoniamnist"][0]["n_channels"]

# Declares the number of epochs and the model's latent dimensions
latent_dims = 50
epochs = 200

# %%
run_GAN_pipeline(train_loader, val_loader, test_loader, n_channels, latent_dims, n_classes, 16, 200, "pneumoniamnist" )

# %%
import torch
import torch.nn as nn
import torchvision.datasets as dset
import torchvision.utils

from PIL import Image
from torch.utils.data import DataLoader
from torchsummary import summary
from torchvision import datasets, transforms
from torchvision.transforms.transforms import Resize
from tqdm import tqdm

class ConvBlock(nn.Module):
    def __init__(self, in_features, out_features, bn=False):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Conv2d(
                in_features, 
                out_features, 
                3, 1, 0
            ),
            nn.BatchNorm2d(out_features) if bn else nn.Identity(),
            nn.LeakyReLU(0.2, inplace=True),
        )
    def forward(self, x):
        return self.layers(x)

class TransConvBlock(nn.Module):
    def __init__(self, in_features, out_features, stride = 1, padding = 1):
        super().__init__()
        self.layers = nn.Sequential(
            nn.ConvTranspose2d(
                in_features, 
                out_features, 
                4,
                stride=stride, 
                padding=padding
            ),
            nn.BatchNorm2d(out_features),
            nn.ReLU(inplace=True),
        )
    def forward(self, x):
        return self.layers(x)

class Discriminator2(nn.Module):
    def __init__(self, n_channels, ndf = 28, img_size = 28):
        super().__init__()
        self.img_size = img_size
        self.layers = nn.Sequential(
            ConvBlock(
                n_channels, 
                ndf, 
                bn=False
            ),
            ConvBlock(
                ndf, 
                ndf * 2
            ),
            ConvBlock(
                ndf * 2, 
                ndf * 4
            ),
            nn.Conv2d(
                ndf * 4, 
                1, 
                3, 
                2, 
                0, 
            ),
            nn.MaxPool2d(3,2,1),
            nn.Conv2d(
                1,1,5
            ),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.layers(x)

class Generator2(nn.Module):
    def __init__(self, z_dim, n_channels, ngf = 28, img_size = 28):
        super(Generator2, self).__init__()
        self.img_size = img_size
        self.layers = nn.Sequential(
            TransConvBlock(
                z_dim, 
                ngf * 8, 
                stride=2, 
                padding=1
            ),
            TransConvBlock(
                ngf * 8, 
                ngf * 4,
                stride=2,
                padding=1
            ),
            TransConvBlock(
                ngf * 4, 
                ngf * 4,
                stride=2,
                padding=0
            ),
            nn.ConvTranspose2d(
                ngf*4, 
                n_channels, 
                3, 
                3, 
                1,
            ),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.layers(x)
    
class ConditionalGenerator2(Generator2):
    def __init__(self, z_dim, n_channels, n_classes, ngf = 32) -> None:
        super().__init__(z_dim * 2, n_channels, ngf=ngf)
        self.embed = nn.Embedding(n_classes, z_dim)
    def forward(self, x, labels):
        embedding = self.embed(labels).unsqueeze(2)#.unsqueeze(3)
        cat = torch.cat(
            [x, embedding.permute(0, 3, 1, 2)], 
            dim=1
        )
        return super().forward(cat)

# %%
summary(Discriminator2(3).cuda(), (3,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 28, 26, 26]             784
#           Identity-2           [-1, 28, 26, 26]               0
#          LeakyReLU-3           [-1, 28, 26, 26]               0
#          ConvBlock-4           [-1, 28, 26, 26]               0
#             Conv2d-5           [-1, 56, 24, 24]          14,168
#           Identity-6           [-1, 56, 24, 24]               0
#          LeakyReLU-7           [-1, 56, 24, 24]               0
#          ConvBlock-8           [-1, 56, 24, 24]               0
#             Conv2d-9          [-1, 112, 22, 22]          56,560
#          Identity-10          [-1, 112, 22, 22]               0
#         LeakyReLU-11          [-1, 112, 22, 22]               0
#         ConvBlock-12          [-1, 112, 22, 22]               0
#            Conv2d-13            [-1, 1, 10, 10]           1,009
#         MaxPool2d-14              [-1, 1, 5, 5]               0
#            Conv2d-15              [-1, 1, 1, 1]              26
#           Sigmoid-16              [-1, 1, 1, 1]               0
# ================================================================
# Total params: 72,547
# Trainable params: 72,547
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.22
# Params size (MB): 0.28
# Estimated Total Size (MB): 3.50
# ----------------------------------------------------------------

# %%
summary(Generator2(100, 3, 10).cuda(), (100, 1, 1))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#    ConvTranspose2d-1             [-1, 80, 2, 2]         128,080
#        BatchNorm2d-2             [-1, 80, 2, 2]             160
#               ReLU-3             [-1, 80, 2, 2]               0
#     TransConvBlock-4             [-1, 80, 2, 2]               0
#    ConvTranspose2d-5             [-1, 40, 4, 4]          51,240
#        BatchNorm2d-6             [-1, 40, 4, 4]              80
#               ReLU-7             [-1, 40, 4, 4]               0
#     TransConvBlock-8             [-1, 40, 4, 4]               0
#    ConvTranspose2d-9           [-1, 40, 10, 10]          25,640
#       BatchNorm2d-10           [-1, 40, 10, 10]              80
#              ReLU-11           [-1, 40, 10, 10]               0
#    TransConvBlock-12           [-1, 40, 10, 10]               0
#   ConvTranspose2d-13            [-1, 3, 28, 28]           1,083
#           Sigmoid-14            [-1, 3, 28, 28]               0
# ================================================================
# Total params: 206,363
# Trainable params: 206,363
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.19
# Params size (MB): 0.79
# Estimated Total Size (MB): 0.97
# ----------------------------------------------------------------
